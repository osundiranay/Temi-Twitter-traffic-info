# %%
#Import libraries 

import json, requests
import time, datetime
import pandas as pd

# Viewing configs for notebook
# %matplotlib inline
# %config InlineBackend.print_figure_kwargs={'facecolor' : 'w'}
# Code below allows multiple console outputs to be generated without print statements
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
json_file = open('here-creds.json')
json_str = json_file.read()
json_data = json.loads(json_str)

# %%
proximity_coords = "34.14892%2C-118.0632%2C23664"

# %%
url = f"https://traffic.api.here.com/traffic/6.0/incidents.json?prox={proximity_coords}&criticality=critical&app_id={json_data['APP_ID']}&app_code={json_data['APP_CODE']}"


#proximity

# %%
res = requests.get(url)
date_requested = time.strftime('%Y-%m-%d')
time_requested = time.strftime('%H:%M') # 24-hour format
date_requested; time_requested
# Out:
# '2019-07-29'
# '17:45'

# %%
res.status_code
# Out:
# 200

# %%
 new_json = res.json()

# %%
print(new_json.keys())
new_json['TRAFFICITEMS'].keys()

#hmaps_json['TRAFFIC_ITEMS']['TRAFFIC_ITEM'];
# Out:
# dict_keys(['TIMESTAMP', 'VERSION', 'TRAFFICITEMS'])
# dict_keys(['TRAFFICITEM'])

# %%
incident_dict = new_json['TRAFFICITEMS']['TRAFFICITEM']
incident_dict
# Out:
# [{'TRAFFICITEMID': 2294581634866155379,
#   'ORIGINALTRAFFICITEMID': 2921151976261408502,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'MISCELLANEOUS',
#   'STARTTIME': '07/30/2019 00:04:55',
#   'ENDTIME': '07/30/2019 05:03:25',
#   'ENTRYTIME': '07/30/2019 00:04:55',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CLOS', 'DESCRIPTION': ''},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '10049',
#       'LOCATIONDESC': 'East Rd',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 401,
#       'DESCRIPTION': 'Closed.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'C1',
#       'EXTENT': '1',
#       'DURATION': 0}},
#     {'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
# ...

# %%
LA_incidents2 = pd.DataFrame(incident_dict)

# %%
LA_incidents2.shape
# Out:
# (44, 15)

# %%
LA_incidents2.keys()
# Out:
# Index(['ABBREVIATION', 'COMMENTS', 'CRITICALITY', 'ENDTIME', 'ENTRYTIME',
#        'LOCATION', 'ORIGINALTRAFFICITEMID', 'RDSTMCLOCATIONS', 'STARTTIME',
#        'TRAFFICITEMDESCRIPTION', 'TRAFFICITEMDETAIL', 'TRAFFICITEMID',
#        'TRAFFICITEMSTATUSSHORTDESC', 'TRAFFICITEMTYPEDESC', 'VERIFIED'],
#       dtype='object')

# %%
LA_incidents2['LOCATION'][3]['DEFINED']['ORIGIN']['ROADWAY']['DESCRIPTION'][0]['content']
# Out:
# 'Angeles Crest Hwy'

# %%
roads = []
for i in range(0,44):
    try:
        word = LA_incidents2['LOCATION'][i]['DEFINED']['ORIGIN']['ROADWAY']['DESCRIPTION'][0]['content']
        roads.append(word)
    except:
        roads.append('unknown')

# %%
closed_road = pd.DataFrame(roads)
closed_road.head()
# Out:
#                     0
# 0       Hacienda Blvd
# 1  San Bernardino Fwy
# 2             unknown
# 3   Angeles Crest Hwy
# 4           Lucas Ave

# %%
LA_incidents2['TRAFFICITEMDESCRIPTION'][43][0]['content']
# Out:
# 'Closed between Los Angeles River and S Alameda St - Closed due to roadwork.'

# %%
start_end = []
for i in range(0,44):
    try:
        word = LA_incidents2['TRAFFICITEMDESCRIPTION'][i][0]['content']
        start_end.append(word)
    except:
        start_end.append('unknown')

# %%
start_end_df = pd.DataFrame(start_end)
start_end_df.head(10)
# Out:
#                                                    0
# 0  Closed at East Rd - Closed. Hazardous driving ...
# 1  At CA-39/Azusa Ave/Exit 36 - Entry ramp closed...
# 2       Closed at E 6th St - Closed due to roadwork.
# 3  Closed between Waterman Fire Rd and NF-3N26c -...
# 4  Closed at W 1st St/Beverly Blvd/Glendale Blvd ...
# 5  Closed between Martin Luther King Jr Blvd and ...
# 6  Closed between E 6th St and US-101/Santa Ana F...
# 7  Closed at East Fork Rd - Closed due to serious...
# 8  Closed between Wilshire Pl and Hoover St - Clo...
# 9  Closed between S Flower St and Tom Bradley Blv...

# %%
start_end_df[0].str.split(" - ", n=1, expand=True)
# Out:
#                                                     0  \
# 0                                   Closed at East Rd
# 1                          At CA-39/Azusa Ave/Exit 36
# 2                                  Closed at E 6th St
# 3        Closed between Waterman Fire Rd and NF-3N26c
# 4       Closed at W 1st St/Beverly Blvd/Glendale Blvd
# 5   Closed between Martin Luther King Jr Blvd and ...
# 6    Closed between E 6th St and US-101/Santa Ana Fwy
# 7                              Closed at East Fork Rd
# 8            Closed between Wilshire Pl and Hoover St
# 9     Closed between S Flower St and Tom Bradley Blvd
# 10  Closed between I-10/San Bernardino Fwy and I-1...
# 11           Closed between Victory Pl and Wilson Ave
# 12      Closed at W 1st St/Beverly Blvd/Glendale Blvd
# 13                            At Barranca St/Exit 37B
# 14                                        At Holt Ave
# 15  Closed between E 1st St and E 3rd St/S Alameda St
# ...

# %%
LA_incidents2['RDSTMCLOCATIONS'][3]['RDSTMC'][0]['ORIGIN']['LOCATIONDESC']
# Out:
# 'Waterman Fire Rd'

# %%
LA_incidents2['RDSTMCLOCATIONS'][0]
# Out:
# {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#     'TABLEID': 6,
#     'LOCATIONID': '10049',
#     'LOCATIONDESC': 'East Rd',
#     'RDSDIRECTION': '+'},
#    'DIRECTION': '-',
#    'ALERTC': {'TRAFFICCODE': 401,
#     'DESCRIPTION': 'Closed.',
#     'ALERTCDURATION': 'L',
#     'ALERTCDIRECTION': 1,
#     'URGENCY': 'U',
#     'UPDATECLASS': 5,
#     'PHRASECODE': 'C1',
#     'EXTENT': '1',
#     'DURATION': 0}},
#   {'ORIGIN': {'EBUCOUNTRYCODE': '1',
#     'TABLEID': 6,
#     'LOCATIONID': '10049',
#     'LOCATIONDESC': 'East Rd',
#     'RDSDIRECTION': '+'},
#    'DIRECTION': '-',
#    'ALERTC': {'TRAFFICCODE': 1001,
#     'QUANTIFIERS': 0,
#     'DESCRIPTION': 'Hazardous driving conditions.',
#     'ALERTCDURATION': 'D',
#     'ALERTCDIRECTION': 2,
#     'URGENCY': 'U',
#     'UPDATECLASS': 14,
#     'PHRASECODE': 'G1',
#     'EXTENT': '1',
#     'DURATION': 0}}]}

# %%
LA_incidents2['RDSTMCLOCATIONS'][3]['RDSTMC'][1]['ALERTC']['DESCRIPTION']
# Out:
# 'Mud slide.'

# %%
incident_origin = []
for i in range(0,44):
    try:
        word = LA_incidents2['RDSTMCLOCATIONS'][i]['RDSTMC'][0]['ORIGIN']['LOCATIONDESC']
        incident_origin.append(word)
    except:
        incident_origin.append('unknown')

# %%
incident_origin_df = pd.DataFrame(incident_origin)

# %%
incident_type = []
for i in range(0,44):
    try:
        word = LA_incidents2['RDSTMCLOCATIONS'][i]['RDSTMC'][1]['ALERTC']['DESCRIPTION']
        incident_type.append(word)
    except:
        incident_type.append('road closed')

# %%
incident_type_df = pd.DataFrame(incident_type)

# %%
locations = pd.DataFrame(list(LA_incidents2['LOCATION']))

# %%
locations.head()
# Out:
#                                              DEFINED  \
# 0  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'cont...
# 1  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'cont...
# 2                                                NaN
# 3  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'cont...
# 4  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'cont...
#
#                                               GEOLOC  \
# 0  {'ORIGIN': {'LATITUDE': 33.976507, 'LONGITUDE'...
# 1  {'ORIGIN': {'LATITUDE': 34.07201, 'LONGITUDE':...
# 2  {'ORIGIN': {'LATITUDE': 34.03853, 'LONGITUDE':...
# 3  {'ORIGIN': {'LATITUDE': 34.25846, 'LONGITUDE':...
# 4  {'ORIGIN': {'LATITUDE': 34.06205, 'LONGITUDE':...
#
#                                         INTERSECTION  \
# 0                                                NaN
# 1                                                NaN
# 2  {'ORIGIN': {'ID': '', 'STREET1': {'ADDRESS1': ...
# 3                                                NaN
# ...

# %%
geo_coor = pd.DataFrame(list(locations['GEOLOC']))

# %%
geo_coor
# Out:
#                                                ORIGIN  \
# 0   {'LATITUDE': 33.976507, 'LONGITUDE': -117.969467}
# 1     {'LATITUDE': 34.07201, 'LONGITUDE': -117.90261}
# 2     {'LATITUDE': 34.03853, 'LONGITUDE': -118.23054}
# 3      {'LATITUDE': 34.25846, 'LONGITUDE': -118.1052}
# 4     {'LATITUDE': 34.06205, 'LONGITUDE': -118.25969}
# 5   {'LATITUDE': 34.013231, 'LONGITUDE': -118.290893}
# 6   {'LATITUDE': 34.038432, 'LONGITUDE': -118.227522}
# 7   {'LATITUDE': 34.199964, 'LONGITUDE': -117.860749}
# 8     {'LATITUDE': 34.06075, 'LONGITUDE': -118.28782}
# 9   {'LATITUDE': 34.054802, 'LONGITUDE': -118.252773}
# 10    {'LATITUDE': 34.06572, 'LONGITUDE': -118.15693}
# 11    {'LATITUDE': 34.19208, 'LONGITUDE': -118.32929}
# 12    {'LATITUDE': 34.06205, 'LONGITUDE': -118.25969}
# 13      {'LATITUDE': 34.072, 'LONGITUDE': -117.88428}
# 14    {'LATITUDE': 34.07032, 'LONGITUDE': -117.86434}
# 15    {'LATITUDE': 34.04856, 'LONGITUDE': -118.23519}
# ...

# %%
geo_coor.keys()
# Out:
# Index(['ORIGIN', 'TO'], dtype='object')

# %%
origin = geo_coor['ORIGIN'].apply(pd.Series)
origin
# Out:
#      LATITUDE   LONGITUDE
# 0   33.976507 -117.969467
# 1   34.072010 -117.902610
# 2   34.038530 -118.230540
# 3   34.258460 -118.105200
# 4   34.062050 -118.259690
# 5   34.013231 -118.290893
# 6   34.038432 -118.227522
# 7   34.199964 -117.860749
# 8   34.060750 -118.287820
# 9   34.054802 -118.252773
# 10  34.065720 -118.156930
# 11  34.192080 -118.329290
# 12  34.062050 -118.259690
# 13  34.072000 -117.884280
# 14  34.070320 -117.864340
# 15  34.048560 -118.235190
# 16  34.054907 -118.251555
# 17  33.958114 -117.958232
# 18  33.936220 -118.094810
# 19  34.064330 -117.812080
# 20  34.054636 -118.251462
# 21  34.063743 -117.811997
# 22  34.068730 -117.861190
# 23  33.935380 -118.090630
# 24  34.155930 -118.336520
# 25  34.036845 -118.221478
# 26  34.038363 -118.231308
# 27  34.155500 -118.336310
# 28  34.013237 -118.291329
# 29  34.191800 -118.331430
# 30  34.002905 -117.904211
# 31  33.934670 -118.090560
# 32  34.061341 -118.258692
# 33  33.996874 -117.904940
# ...

# %%
geo_coor['TO']
# Out:
# 0     [{'LATITUDE': 33.958114, 'LONGITUDE': -117.958...
# 1     [{'LATITUDE': 34.07201, 'LONGITUDE': -117.90261}]
# 2     [{'LATITUDE': 34.03839, 'LONGITUDE': -118.23273}]
# 3      [{'LATITUDE': 34.37332, 'LONGITUDE': -117.7524}]
# 4     [{'LATITUDE': 34.06205, 'LONGITUDE': -118.25969}]
# 5     [{'LATITUDE': 34.013237, 'LONGITUDE': -118.291...
# 6     [{'LATITUDE': 34.036845, 'LONGITUDE': -118.221...
# 7     [{'LATITUDE': 34.23911, 'LONGITUDE': -117.85131}]
# 8      [{'LATITUDE': 34.06079, 'LONGITUDE': -118.2842}]
# 9     [{'LATITUDE': 34.054668, 'LONGITUDE': -118.251...
# 10    [{'LATITUDE': 34.06708, 'LONGITUDE': -118.15434}]
# 11     [{'LATITUDE': 34.1918, 'LONGITUDE': -118.33143}]
# 12    [{'LATITUDE': 34.06205, 'LONGITUDE': -118.25969}]
# 13      [{'LATITUDE': 34.072, 'LONGITUDE': -117.88428}]
# 14    [{'LATITUDE': 34.07032, 'LONGITUDE': -117.86434}]
# 15    [{'LATITUDE': 34.04718, 'LONGITUDE': -118.23516}]
# 16    [{'LATITUDE': 34.054636, 'LONGITUDE': -118.251...
# ...

# %%
# Add a strat/end column and create an incident column thats the index 
origin['start_end'] = 'start'
origin['incident'] = origin.index
origin.shape
# Out:
# (44, 4)

# %%
to = pd.DataFrame(s for k, v in geo_coor['TO'].items() for s in v)

# %%
to['start_end'] = 'end'
to['incident'] = to.index
to.head()
# Out:
#     LATITUDE   LONGITUDE start_end  incident
# 0  33.958114 -117.958232       end         0
# 1  34.072010 -117.902610       end         1
# 2  34.038390 -118.232730       end         2
# 3  34.373320 -117.752400       end         3
# 4  34.062050 -118.259690       end         4

# %%
total_locations = pd.concat([origin, to])

# %%
total_locations[total_locations['incident'] == 3]
# Out:
#    LATITUDE  LONGITUDE start_end  incident
# 3  34.25846  -118.1052     start         3
# 3  34.37332  -117.7524       end         3

# %%
# total_locations.to_csv('live_here_locations.csv')
