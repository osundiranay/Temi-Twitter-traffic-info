# %%
#Import libraries 

import json, requests
import time, datetime
import pandas as pd

# Viewing configs for notebook
# %matplotlib inline
# %config InlineBackend.print_figure_kwargs={'facecolor' : 'w'}
# Code below allows multiple console outputs to be generated without print statements
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
json_file = open('woolsey_fire_traffic_map/creds.json')
json_str = json_file.read()
json_data = json.loads(json_str)

# %%
proximity_coords = "34.1643%2C-118.6919%2C23664"

# %%
url = f"https://traffic.api.here.com/traffic/6.0/incidents.json?prox={proximity_coords}&criticality=critical&app_id={json_data['APP_ID']}&app_code={json_data['APP_CODE']}"


#proximity

# %%
res = requests.get(url)
date_requested = time.strftime('%Y-%m-%d')
time_requested = time.strftime('%H:%M') # 24-hour format
date_requested; time_requested
# Out:
# '2019-07-23'
# '22:04'

# %%
res.status_code
# Out:
# 200

# %%
prox_json = res.json()

# %%
print(prox_json.keys())
prox_json['TRAFFICITEMS'].keys()

#hmaps_json['TRAFFIC_ITEMS']['TRAFFIC_ITEM'];
# Out:
# dict_keys(['TIMESTAMP', 'VERSION', 'TRAFFICITEMS'])
# dict_keys(['TRAFFICITEM'])

# %%
incident_dict = prox_json['TRAFFICITEMS']['TRAFFICITEM']
incident_dict
# Out:
# [{'TRAFFICITEMID': 3532020189718437840,
#   'ORIGINALTRAFFICITEMID': 3501104932856112683,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '09/21/2018 16:00:00',
#   'ENDTIME': '07/24/2019 09:18:40',
#   'ENTRYTIME': '07/24/2019 04:20:29',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Constellation Blvd'},
#      'STREET2': {'ADDRESS1': 'Santa Monica Blvd'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Constellation Blvd'},
#      'STREET2': {'ADDRESS1': 'CA-2'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.05869, 'LONGITUDE': -118.41584},
#     'TO': [{'LATITUDE': 34.06034, 'LONGITUDE': -118.41357}]},
#    'POLITICALBOUNDARY': {'METROAREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles'},
#    'NAVTECH': {'EDGE': {'EDGEID': ['1152045210',
#       '1152045211',
#       '1152045209',
#       '870233672',
#       '870233673']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between Santa Monica Blvd and CA-2 - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between Santa Monica Blvd and CA-2 - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 1508340853331347747,
#   'ORIGINALTRAFFICITEMID': 1508340853331347747,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/24/2019 04:56:29',
#   'ENDTIME': '07/28/2019 04:55:59',
#   'ENTRYTIME': '07/24/2019 04:56:29',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '06441',
#       'LOCATIONDESC': 'CA-1/Pacific Coast Hwy',
#       'RDSDIRECTION': '-'},
#      'TO': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '06444',
#       'LOCATIONDESC': 'Fernwood Pacific Dr',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 401,
#       'DESCRIPTION': 'Closed.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'C1',
#       'EXTENT': '3',
#       'DURATION': 0}},
#     {'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '06441',
#       'LOCATIONDESC': 'CA-1/Pacific Coast Hwy',
#       'RDSDIRECTION': '-'},
#      'TO': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '06444',
#       'LOCATIONDESC': 'Fernwood Pacific Dr',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 742,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Roadwork. Single alternate lane traffic.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 2,
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'E1.E14',
#       'EXTENT': '3',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'Topanga Canyon Blvd',
#         'TYPE': 'NTCSA'},
#        {'content': 'Topanga Canyon Blvd', 'TYPE': 'RDSGN'},
#        {'content': 'Topanga Canyon Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 3013},
#      'POINT': {'DESCRIPTION': [{'content': 'CA-1/Pacific Coast Hwy',
#         'TYPE': 'NTCSA'},
#        {'content': 'CA-1/Pacific Coast Hwy', 'TYPE': 'RDSGN'},
#        {'content': 'CA-1/Pacific Coast Hwy', 'TYPE': 'LOCAL'},
#        {'content': 'Topanga Canyon Blvd', 'TYPE': 'BNAME'}],
#       'ID': 6441},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'S Topanga Canyon Blvd',
#         'TYPE': 'NTCSA'},
#        {'content': 'S Topanga Canyon Blvd', 'TYPE': 'RDSGN'},
#        {'content': 'S Topanga Canyon Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 3013},
#      'POINT': {'DESCRIPTION': [{'content': 'Fernwood Pacific Dr',
#         'TYPE': 'NTCSA'},
#        {'content': 'Fernwood Pacific Dr', 'TYPE': 'RDSGN'},
#        {'content': 'Fernwood Pacific Dr', 'TYPE': 'LOCAL'},
#        {'content': 'S Topanga Canyon Blvd', 'TYPE': 'BNAME'}],
#       'ID': 6444},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.04012, 'LONGITUDE': -118.57928},
#     'TO': [{'LATITUDE': 34.082328, 'LONGITUDE': -118.598688}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['24047077',
#       '762540762',
#       '762540763',
#       '762540761',
#       '1147182185',
#       '1147182186',
#       '865292982',
#       '865292983',
#       '865292980',
#       '936058627',
#       '1044838488',
#       '865292986',
#       '776744754',
#       '1198256502',
#       '1198256503',
#       '707394683',
#       '707394680',
#       '1198257313',
#       '1198257314',
#       '1198350920',
#       '1198350921',
#       '936056184',
#       '865292971',
#       '865292972',
#       '865292973',
#       '865292974',
#       '865292975',
#       '776744731',
#       '865292976',
#       '932451805',
#       '932451806',
#       '932451804',
#       '865292978',
#       '865292979',
#       '932451807',
#       '932451808',
#       '24154279',
#       '128788117',
#       '1198257668',
#       '1198257669',
#       '1075761556',
#       '1075761557',
#       '1075761554']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between CA-1/Pacific Coast Hwy and Fernwood Pacific Dr - Closed due to roadwork. Single alternate lane traffic.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between CA-1/Pacific Coast Hwy and Fernwood Pacific Dr - Closed due to roadwork. Single alternate lane traffic.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork. Single alternate lane traffic.',
#     'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 3550270994482397702,
#   'ORIGINALTRAFFICITEMID': 1490074230888900810,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '09/21/2018 16:00:00',
#   'ENDTIME': '07/24/2019 09:18:40',
#   'ENTRYTIME': '07/24/2019 04:20:29',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Constellation Blvd'},
#      'STREET2': {'ADDRESS1': 'CA-2'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Constellation Blvd'},
#      'STREET2': {'ADDRESS1': 'Santa Monica Blvd'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.06034, 'LONGITUDE': -118.41357},
#     'TO': [{'LATITUDE': 34.05869, 'LONGITUDE': -118.41584}]},
#    'POLITICALBOUNDARY': {'METROAREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles'},
#    'NAVTECH': {'EDGE': {'EDGEID': ['870233673',
#       '870233672',
#       '1152045209',
#       '1152045211',
#       '1152045210']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between CA-2 and Santa Monica Blvd - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between CA-2 and Santa Monica Blvd - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 2316539471152701513,
#   'ORIGINALTRAFFICITEMID': 3336447423575777310,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'MISCELLANEOUS',
#   'STARTTIME': '07/24/2019 04:20:29',
#   'ENDTIME': '07/24/2019 09:18:40',
#   'ENTRYTIME': '07/24/2019 04:20:29',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CLOS', 'DESCRIPTION': ''},
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Malibu'},
#      'STREET2': {'ADDRESS1': 'Mesa Peak Pkwy'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Corral Canyon Rd'},
#      'STREET2': {'ADDRESS1': 'Tistou Trl/Lookout Rd '},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.07898, 'LONGITUDE': -118.75556},
#     'TO': [{'LATITUDE': 34.066566, 'LONGITUDE': -118.754557}]},
#    'POLITICALBOUNDARY': {'METROAREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles'},
#    'NAVTECH': {'EDGE': {'EDGEID': ['37819970',
#       '1049850018',
#       '1049886196',
#       '1049886198']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'INCIDENT': {'RESPONSEVEHICLES': False,
#     'MISCELLANEOUSINCIDENT': {'MISCELLANEOUSTYPEDESC': ''}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between Mesa Peak Pkwy and Tistou Trl/Lookout Rd  - Closed. Hazardous driving conditions.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between Mesa Peak Pkwy and Tistou Trl/Lookout Rd  - Closed. Hazardous driving conditions.',
#     'TYPE': 'desc'},
#    {'content': 'Closed. Hazardous driving conditions.',
#     'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 2846997458634124110,
#   'ORIGINALTRAFFICITEMID': 2846997458634124110,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/24/2019 04:00:00',
#   'ENDTIME': '07/24/2019 12:00:00',
#   'ENTRYTIME': '07/24/2019 04:01:44',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '19499',
#       'LOCATIONDESC': 'CA-14/Antelope Valley Fwy NB',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 735,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Closed due to roadwork.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'E1.C1',
#       'EXTENT': '0',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'I-5',
#         'TYPE': 'NTCSA'},
#        {'content': 'I-5', 'TYPE': 'RDSGN'},
#        {'content': 'I-5', 'TYPE': 'LOCAL'}],
#       'ID': 19498},
#      'POINT': {'DESCRIPTION': [{'content': 'CA-14', 'TYPE': 'NTCSA'},
#        {'content': 'CA-14', 'TYPE': 'RDSGN'},
#        {'content': 'CA-14', 'TYPE': 'LOCAL'},
#        {'content': 'I-5', 'TYPE': 'BNAME'}],
#       'ID': 19499},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'CA-14/ANTELOPE VALLEY FWY NB',
#         'TYPE': 'LOCAL'},
#        {'content': 'CA-14/ANTELOPE VALLEY FWY NB', 'TYPE': 'NTCSA'},
#        {'content': 'CA-14/ANTELOPE VALLEY FWY NB', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'RMP',
#       'DESCRIPTION': 'ramp(freeway connector or defined off-ramp)'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'I-5 Southbound',
#         'TYPE': 'NTCSA'},
#        {'content': 'I-5 Southbound', 'TYPE': 'RDSGN'},
#        {'content': 'I-5 Southbound', 'TYPE': 'LOCAL'}],
#       'ID': 19498},
#      'POINT': {'DESCRIPTION': [{'content': 'CA-14/Antelope Valley Fwy NB',
#         'TYPE': 'NTCSA'},
#        {'content': 'CA-14/Antelope Valley Fwy NB', 'TYPE': 'RDSGN'},
#        {'content': 'CA-14/Antelope Valley Fwy NB', 'TYPE': 'LOCAL'},
#        {'content': 'I-5 Southbound', 'TYPE': 'BNAME'}],
#       'ID': 19499},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'CA-14/ANTELOPE VALLEY FWY NB',
#         'TYPE': 'LOCAL'},
#        {'content': 'CA-14/ANTELOPE VALLEY FWY NB', 'TYPE': 'NTCSA'},
#        {'content': 'CA-14/ANTELOPE VALLEY FWY NB', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'RMP',
#       'DESCRIPTION': 'ramp(freeway connector or defined off-ramp)'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.33766, 'LONGITUDE': -118.5144},
#     'TO': [{'LATITUDE': 34.33527, 'LONGITUDE': -118.51109}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['947139076', '947139075']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Ramp  closed to CA-14/Antelope Valley Fwy NB - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Ramp  closed to CA-14/Antelope Valley Fwy NB - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 3651053883171215030,
#   'ORIGINALTRAFFICITEMID': 3651053883171215030,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/24/2019 04:56:29',
#   'ENDTIME': '07/28/2019 04:55:59',
#   'ENTRYTIME': '07/24/2019 04:56:29',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '06443',
#       'LOCATIONDESC': 'Fernwood Pacific Dr',
#       'RDSDIRECTION': '+'},
#      'TO': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '06441',
#       'LOCATIONDESC': 'CA-1/Pacific Coast Hwy',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 401,
#       'DESCRIPTION': 'Closed.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'C1',
#       'EXTENT': '2',
#       'DURATION': 0}},
#     {'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '06443',
#       'LOCATIONDESC': 'Fernwood Pacific Dr',
#       'RDSDIRECTION': '+'},
#      'TO': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '06441',
#       'LOCATIONDESC': 'CA-1/Pacific Coast Hwy',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 742,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Roadwork. Single alternate lane traffic.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 2,
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'E1.E14',
#       'EXTENT': '2',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'S Topanga Canyon Blvd',
#         'TYPE': 'NTCSA'},
#        {'content': 'S Topanga Canyon Blvd', 'TYPE': 'RDSGN'},
#        {'content': 'S Topanga Canyon Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 3013},
#      'POINT': {'DESCRIPTION': [{'content': 'Fernwood Pacific Dr',
#         'TYPE': 'NTCSA'},
#        {'content': 'Fernwood Pacific Dr', 'TYPE': 'RDSGN'},
#        {'content': 'Fernwood Pacific Dr', 'TYPE': 'LOCAL'},
#        {'content': 'S Topanga Canyon Blvd', 'TYPE': 'BNAME'}],
#       'ID': 6443},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'Topanga Canyon Blvd',
#         'TYPE': 'NTCSA'},
#        {'content': 'Topanga Canyon Blvd', 'TYPE': 'RDSGN'},
#        {'content': 'Topanga Canyon Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 3013},
#      'POINT': {'DESCRIPTION': [{'content': 'CA-1/Pacific Coast Hwy',
#         'TYPE': 'NTCSA'},
#        {'content': 'CA-1/Pacific Coast Hwy', 'TYPE': 'RDSGN'},
#        {'content': 'CA-1/Pacific Coast Hwy', 'TYPE': 'LOCAL'},
#        {'content': 'Topanga Canyon Blvd', 'TYPE': 'BNAME'}],
#       'ID': 6441},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.082328, 'LONGITUDE': -118.598688},
#     'TO': [{'LATITUDE': 34.04012, 'LONGITUDE': -118.57928}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['1075761554',
#       '1075761557',
#       '1075761556',
#       '1198257669',
#       '1198257668',
#       '128788117',
#       '24154279',
#       '932451808',
#       '932451807',
#       '865292979',
#       '865292978',
#       '932451804',
#       '932451806',
#       '932451805',
#       '865292976',
#       '776744731',
#       '865292975',
#       '865292974',
#       '865292973',
#       '865292972',
#       '865292971',
#       '936056184',
#       '1198350921',
#       '1198350920',
#       '1198257314',
#       '1198257313',
#       '707394680',
#       '707394683',
#       '1198256503',
#       '1198256502',
#       '776744754',
#       '865292986',
#       '1044838488',
#       '936058627',
#       '865292980',
#       '865292983',
#       '865292982',
#       '1147182186',
#       '1147182185',
#       '762540761',
#       '762540763',
#       '762540762',
#       '24047077']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between Fernwood Pacific Dr and CA-1/Pacific Coast Hwy - Closed due to roadwork. Single alternate lane traffic.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between Fernwood Pacific Dr and CA-1/Pacific Coast Hwy - Closed due to roadwork. Single alternate lane traffic.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork. Single alternate lane traffic.',
#     'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 4141747805352232052,
#   'ORIGINALTRAFFICITEMID': 4141747805352232052,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/24/2019 04:00:00',
#   'ENDTIME': '07/24/2019 12:00:00',
#   'ENTRYTIME': '07/24/2019 04:01:44',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '23040',
#       'LOCATIONDESC': 'CA-14',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 735,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Closed due to roadwork.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'E1.C1',
#       'EXTENT': '0',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'I-5 SB and I-5-TRUCK SB',
#         'TYPE': 'NTCSA'},
#        {'content': 'I-5 SB and I-5-TRUCK SB', 'TYPE': 'RDSGN'},
#        {'content': 'I-5 SB and I-5-TRUCK SB', 'TYPE': 'LOCAL'}],
#       'ID': 23039},
#      'POINT': {'DESCRIPTION': [{'content': 'CA-14/Antelope Valley Fwy NB',
#         'TYPE': 'NTCSA'},
#        {'content': 'CA-14/Antelope Valley Fwy NB', 'TYPE': 'RDSGN'},
#        {'content': 'CA-14/Antelope Valley Fwy NB', 'TYPE': 'LOCAL'},
#        {'content': 'I-5 SB and I-5-TRUCK SB', 'TYPE': 'BNAME'}],
#       'ID': 23040},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'CA-14/ANTELOPE VALLEY FWY NB',
#         'TYPE': 'LOCAL'},
#        {'content': 'CA-14/ANTELOPE VALLEY FWY NB', 'TYPE': 'NTCSA'},
#        {'content': 'CA-14/ANTELOPE VALLEY FWY NB', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'RMP',
#       'DESCRIPTION': 'ramp(freeway connector or defined off-ramp)'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'I-5', 'TYPE': 'NTCSA'},
#        {'content': 'I-5', 'TYPE': 'RDSGN'},
#        {'content': 'I-5', 'TYPE': 'LOCAL'}],
#       'ID': 23039},
#      'POINT': {'DESCRIPTION': [{'content': 'CA-14', 'TYPE': 'NTCSA'},
#        {'content': 'CA-14', 'TYPE': 'RDSGN'},
#        {'content': 'CA-14', 'TYPE': 'LOCAL'},
#        {'content': 'I-5', 'TYPE': 'BNAME'}],
#       'ID': 23040},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'CA-14/ANTELOPE VALLEY FWY NB',
#         'TYPE': 'LOCAL'},
#        {'content': 'CA-14/ANTELOPE VALLEY FWY NB', 'TYPE': 'NTCSA'},
#        {'content': 'CA-14/ANTELOPE VALLEY FWY NB', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'RMP',
#       'DESCRIPTION': 'ramp(freeway connector or defined off-ramp)'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.33527, 'LONGITUDE': -118.51109},
#     'TO': [{'LATITUDE': 34.33973, 'LONGITUDE': -118.50654}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['776739174',
#       '859637849',
#       '859637848',
#       '859547403',
#       '981609060',
#       '981609061',
#       '1083832603',
#       '1083832604',
#       '1148876156',
#       '1148876157',
#       '947139065',
#       '128810463']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Ramp  closed to CA-14 - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Ramp  closed to CA-14 - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]}]

# %%
malibu_incidents = pd.DataFrame(incident_dict)

# %%
malibu_incidents.columns
# Out:
# Index(['ABBREVIATION', 'CRITICALITY', 'ENDTIME', 'ENTRYTIME', 'LOCATION',
#        'ORIGINALTRAFFICITEMID', 'RDSTMCLOCATIONS', 'STARTTIME',
#        'TRAFFICITEMDESCRIPTION', 'TRAFFICITEMDETAIL', 'TRAFFICITEMID',
#        'TRAFFICITEMSTATUSSHORTDESC', 'TRAFFICITEMTYPEDESC', 'VERIFIED'],
#       dtype='object')

# %%
malibu_incidents.isnull().sum()
# Out:
# ABBREVIATION                  0
# CRITICALITY                   0
# ENDTIME                       0
# ENTRYTIME                     0
# LOCATION                      0
# ORIGINALTRAFFICITEMID         0
# RDSTMCLOCATIONS               3
# STARTTIME                     0
# TRAFFICITEMDESCRIPTION        0
# TRAFFICITEMDETAIL             0
# TRAFFICITEMID                 0
# TRAFFICITEMSTATUSSHORTDESC    0
# TRAFFICITEMTYPEDESC           0
# VERIFIED                      0
# dtype: int64

# %%
locations = pd.DataFrame(list(malibu_incidents['LOCATION']))

# %%
locations.head()
# Out:
#                                              DEFINED  \
# 0                                                NaN
# 1  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'cont...
# 2                                                NaN
# 3                                                NaN
# 4  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'cont...
#
#                                               GEOLOC  \
# 0  {'ORIGIN': {'LATITUDE': 34.05869, 'LONGITUDE':...
# 1  {'ORIGIN': {'LATITUDE': 34.04012, 'LONGITUDE':...
# 2  {'ORIGIN': {'LATITUDE': 34.06034, 'LONGITUDE':...
# 3  {'ORIGIN': {'LATITUDE': 34.07898, 'LONGITUDE':...
# 4  {'ORIGIN': {'LATITUDE': 34.33766, 'LONGITUDE':...
#
#                                         INTERSECTION  \
# 0  {'ORIGIN': {'ID': '', 'STREET1': {'ADDRESS1': ...
# 1                                                NaN
# 2  {'ORIGIN': {'ID': '', 'STREET1': {'ADDRESS1': ...
# 3  {'ORIGIN': {'ID': '', 'STREET1': {'ADDRESS1': ...
# 4                                                NaN
#
#                                              NAVTECH  \
# 0  {'EDGE': {'EDGEID': ['1152045210', '1152045211...
# 1  {'EDGE': {'EDGEID': ['24047077', '762540762', ...
# 2  {'EDGE': {'EDGEID': ['870233673', '870233672',...
# 3  {'EDGE': {'EDGEID': ['37819970', '1049850018',...
# 4  {'EDGE': {'EDGEID': ['947139076', '947139075']...
#
#                                    POLITICALBOUNDARY
# 0  {'METROAREA': {'value': '', 'ID': 6}, 'COUNTY'...
# 1                                                NaN
# 2  {'METROAREA': {'value': '', 'ID': 6}, 'COUNTY'...
# 3  {'METROAREA': {'value': '', 'ID': 6}, 'COUNTY'...
# 4                                                NaN

# %%
locations[]

# %%
geo_coor = pd.DataFrame(list(locations['GEOLOC']))

# %%
geo_coor
# Out:
#                                               ORIGIN  \
# 0    {'LATITUDE': 34.05869, 'LONGITUDE': -118.41584}
# 1    {'LATITUDE': 34.04012, 'LONGITUDE': -118.57928}
# 2    {'LATITUDE': 34.06034, 'LONGITUDE': -118.41357}
# 3    {'LATITUDE': 34.07898, 'LONGITUDE': -118.75556}
# 4     {'LATITUDE': 34.33766, 'LONGITUDE': -118.5144}
# 5  {'LATITUDE': 34.082328, 'LONGITUDE': -118.598688}
# 6    {'LATITUDE': 34.33527, 'LONGITUDE': -118.51109}
#
#                                                   TO
# 0  [{'LATITUDE': 34.06034, 'LONGITUDE': -118.41357}]
# 1  [{'LATITUDE': 34.082328, 'LONGITUDE': -118.598...
# 2  [{'LATITUDE': 34.05869, 'LONGITUDE': -118.41584}]
# 3  [{'LATITUDE': 34.066566, 'LONGITUDE': -118.754...
# 4  [{'LATITUDE': 34.33527, 'LONGITUDE': -118.51109}]
# 5  [{'LATITUDE': 34.04012, 'LONGITUDE': -118.57928}]
# 6  [{'LATITUDE': 34.33973, 'LONGITUDE': -118.50654}]

# %%
geo_coor.keys()
# Out:
# Index(['ORIGIN', 'TO'], dtype='object')

# %%
origin = geo_coor['ORIGIN'].apply(pd.Series)
origin
# Out:
#     LATITUDE   LONGITUDE
# 0  34.058690 -118.415840
# 1  34.040120 -118.579280
# 2  34.060340 -118.413570
# 3  34.078980 -118.755560
# 4  34.337660 -118.514400
# 5  34.082328 -118.598688
# 6  34.335270 -118.511090

# %%
geo_coor['TO']
# Out:
# 0    [{'LATITUDE': 34.06034, 'LONGITUDE': -118.41357}]
# 1    [{'LATITUDE': 34.082328, 'LONGITUDE': -118.598...
# 2    [{'LATITUDE': 34.05869, 'LONGITUDE': -118.41584}]
# 3    [{'LATITUDE': 34.066566, 'LONGITUDE': -118.754...
# 4    [{'LATITUDE': 34.33527, 'LONGITUDE': -118.51109}]
# 5    [{'LATITUDE': 34.04012, 'LONGITUDE': -118.57928}]
# 6    [{'LATITUDE': 34.33973, 'LONGITUDE': -118.50654}]
# Name: TO, dtype: object

# %%
# Add a strat/end column and create an incident column thats the index 
origin['start_end'] = 'start'
origin['incident'] = origin.index
origin
# Out:
#     LATITUDE   LONGITUDE start_end  incident
# 0  34.058690 -118.415840     start         0
# 1  34.040120 -118.579280     start         1
# 2  34.060340 -118.413570     start         2
# 3  34.078980 -118.755560     start         3
# 4  34.337660 -118.514400     start         4
# 5  34.082328 -118.598688     start         5
# 6  34.335270 -118.511090     start         6

# %%
to = pd.DataFrame(s for k, v in geo_coor['TO'].items() for s in v)

# %%
to['start_end'] = 'end'
to['incident'] = to.index
to
# Out:
#     LATITUDE   LONGITUDE start_end  incident
# 0  34.060340 -118.413570       end         0
# 1  34.082328 -118.598688       end         1
# 2  34.058690 -118.415840       end         2
# 3  34.066566 -118.754557       end         3
# 4  34.335270 -118.511090       end         4
# 5  34.040120 -118.579280       end         5
# 6  34.339730 -118.506540       end         6

# %%
total_locations = pd.concat([origin, to])

# %%
total_locations.to_csv('live_here_locations.csv')
