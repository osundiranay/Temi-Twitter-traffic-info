# %% [markdown]
# ## Scraping Live Road Closures from Here.com

# %% [markdown]
# _Author: Rachel Koenig_

# %%
#Import libraries 
import json, requests
import time, datetime
import pandas as pd

# Code below allows multiple console outputs to be generated without print statements
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# An api key for Here.com is required to run this notebook.  Visit https://developer.here.com/ to create one.

# %%
# pull in our private API credentials
json_file = open('creds/here-creds.json')
json_str = json_file.read()
json_data = json.loads(json_str)

# %%
# Specify latitude and longitude coordinates for Los Angeles, CA.  
# Here.com will search a radius around this point
proximity_coords = "34.14892%2C-118.0632%2C23664"

# %%
url = f"https://traffic.api.here.com/traffic/6.0/incidents.json?prox={proximity_coords}&criticality=critical&app_id={json_data['APP_ID']}&app_code={json_data['APP_CODE']}"

# %%
# Scrape Here.com for any traffic incidents in the last 24 hours for the set proximity
res = requests.get(url)
date_requested = time.strftime('%Y-%m-%d') 
time_requested = time.strftime('%H:%M') 
date_requested; time_requested #print date & time of request
# Out:
# '2019-07-31'
# '14:05'

# %%
# Check for 200 status 
res.status_code
# Out:
# 200

# %%
 new_json = res.json()

# %%
print(new_json.keys())
new_json['TRAFFICITEMS'].keys()
# Out:
# dict_keys(['TIMESTAMP', 'VERSION', 'TRAFFICITEMS'])
# dict_keys(['TRAFFICITEM'])

# %%
# Turn json into dictionary 
incident_dict = new_json['TRAFFICITEMS']['TRAFFICITEM']
incident_dict
# Out:
# [{'TRAFFICITEMID': 2028247178486333156,
#   'ORIGINALTRAFFICITEMID': 970920204488413198,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'MISCELLANEOUS',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'MISC', 'DESCRIPTION': ''},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '23635',
#       'LOCATIONDESC': 'W Sierra Madre Ave/Silverfish',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 965,
#       'DESCRIPTION': 'Closed due to serious fire.',
#       'ALERTCDURATION': 'D',
#       'ALERTCDIRECTION': 2,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'F16.C1',
#       'EXTENT': '1',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'Pasadena',
#         'TYPE': 'NTCSA'},
#        {'content': 'Pasadena', 'TYPE': 'RDSGN'},
#        {'content': 'Pasadena', 'TYPE': 'LOCAL'}],
#       'ID': 23634},
#      'POINT': {'DESCRIPTION': [{'content': 'East Fork Rd', 'TYPE': 'NTCSA'},
#        {'content': 'East Fork Rd', 'TYPE': 'RDSGN'},
#        {'content': 'East Fork Rd', 'TYPE': 'LOCAL'},
#        {'content': 'Pasadena', 'TYPE': 'BNAME'}],
#       'ID': 23635},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'Pasadena',
#         'TYPE': 'NTCSA'},
#        {'content': 'Pasadena', 'TYPE': 'RDSGN'},
#        {'content': 'Pasadena', 'TYPE': 'LOCAL'}],
#       'ID': 23634},
#      'POINT': {'DESCRIPTION': [{'content': 'W Sierra Madre Ave/Silverfish',
#         'TYPE': 'NTCSA'},
#        {'content': 'W Sierra Madre Ave/Silverfish', 'TYPE': 'RDSGN'},
#        {'content': 'W Sierra Madre Ave/Silverfish', 'TYPE': 'LOCAL'},
#        {'content': 'Pasadena', 'TYPE': 'BNAME'}],
#       'ID': 23635},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.23911, 'LONGITUDE': -117.85131},
#     'TO': [{'LATITUDE': 34.199964, 'LONGITUDE': -117.860748}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['775815005',
#       '775815008',
#       '775815007',
#       '941563135',
#       '941563134',
#       '128793383',
#       '23998410',
#       '24003588']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'INCIDENT': {'RESPONSEVEHICLES': False,
#     'MISCELLANEOUSINCIDENT': {'MISCELLANEOUSTYPEDESC': ''}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed at W Sierra Madre Ave/Silverfish - Closed due to serious fire.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed at W Sierra Madre Ave/Silverfish - Closed due to serious fire.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to serious fire.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 3003578685978064202,
#   'ORIGINALTRAFFICITEMID': 328162798865147576,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'MISCELLANEOUS',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CLOS', 'DESCRIPTION': ''},
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Garey St'},
#      'STREET2': {'ADDRESS1': 'E 1st St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Garey St'},
#      'STREET2': {'ADDRESS1': 'E 3rd St/S Alameda St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.04856, 'LONGITUDE': -118.23519},
#     'TO': [{'LATITUDE': 34.04718, 'LONGITUDE': -118.23516}]},
#    'POLITICALBOUNDARY': {'METROAREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles'},
#    'NAVTECH': {'EDGE': {'EDGEID': ['23907850']}, 'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'INCIDENT': {'RESPONSEVEHICLES': False,
#     'MISCELLANEOUSINCIDENT': {'MISCELLANEOUSTYPEDESC': ''}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between E 1st St and E 3rd St/S Alameda St - Closed.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between E 1st St and E 3rd St/S Alameda St - Closed.',
#     'TYPE': 'desc'},
#    {'content': 'Closed.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 2500703839060871312,
#   'ORIGINALTRAFFICITEMID': 4295499166299776111,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Ramona Rd'},
#      'STREET2': {'ADDRESS1': 'I-10/San Bernardino Fwy'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Ramona Rd'},
#      'STREET2': {'ADDRESS1': 'I-10/San Bernardino Fwy/Bus Ln'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.06572, 'LONGITUDE': -118.15693},
#     'TO': [{'LATITUDE': 34.06708, 'LONGITUDE': -118.15434}]},
#    'POLITICALBOUNDARY': {'METROAREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles'},
#    'NAVTECH': {'EDGE': {'EDGEID': ['955186417', '23910120']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between I-10/San Bernardino Fwy and I-10/San Bernardino Fwy/Bus Ln - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between I-10/San Bernardino Fwy and I-10/San Bernardino Fwy/Bus Ln - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 3375569987861993588,
#   'ORIGINALTRAFFICITEMID': 3982135750239913208,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'MISCELLANEOUS',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CLOS', 'DESCRIPTION': ''},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '05747',
#       'LOCATIONDESC': 'CA-39/Azusa Ave/Exit 36',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 406,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Entry ramp closed.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 8,
#       'PHRASECODE': 'C6',
#       'EXTENT': '0',
#       'DURATION': 0}},
#     {'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '05747',
#       'LOCATIONDESC': 'CA-39/Azusa Ave/Exit 36',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 803,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Construction work.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'UPDATECLASS': 11,
#       'PHRASECODE': 'E11',
#       'EXTENT': '0',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'San Bernardino Fwy',
#         'TYPE': 'NTCSA'},
#        {'content': 'San Bernardino Fwy', 'TYPE': 'RDSGN'},
#        {'content': 'San Bernardino Fwy', 'TYPE': 'LOCAL'}],
#       'ID': 91},
#      'POINT': {'DESCRIPTION': [{'content': 'CA-39/Azusa Ave/Exit 36',
#         'TYPE': 'NTCSA'},
#        {'content': 'CA-39/Azusa Ave/Exit 36', 'TYPE': 'RDSGN'},
#        {'content': 'CA-39/Azusa Ave/Exit 36', 'TYPE': 'LOCAL'},
#        {'content': 'San Bernardino Fwy', 'TYPE': 'BNAME'}],
#       'ID': 5747},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'San Bernardino Fwy',
#         'TYPE': 'NTCSA'},
#        {'content': 'San Bernardino Fwy', 'TYPE': 'RDSGN'},
#        {'content': 'San Bernardino Fwy', 'TYPE': 'LOCAL'}],
#       'ID': 91},
#      'POINT': {'DESCRIPTION': [{'content': 'CA-39/Azusa Ave/Exit 36',
#         'TYPE': 'NTCSA'},
#        {'content': 'CA-39/Azusa Ave/Exit 36', 'TYPE': 'RDSGN'},
#        {'content': 'CA-39/Azusa Ave/Exit 36', 'TYPE': 'LOCAL'},
#        {'content': 'San Bernardino Fwy', 'TYPE': 'BNAME'}],
#       'ID': 5747},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.07201, 'LONGITUDE': -117.90261},
#     'TO': [{'LATITUDE': 34.07201, 'LONGITUDE': -117.90261}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['24041211']}, 'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': False,
#    'INCIDENT': {'RESPONSEVEHICLES': False,
#     'MISCELLANEOUSINCIDENT': {'MISCELLANEOUSTYPEDESC': ''}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'At CA-39/Azusa Ave/Exit 36 - Entry ramp closed. Construction work.',
#     'TYPE': 'short_desc'},
#    {'content': 'At CA-39/Azusa Ave/Exit 36 - Entry ramp closed. Construction work.',
#     'TYPE': 'desc'},
#    {'content': 'Entry ramp closed. Construction work.',
#     'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 2036300448175018924,
#   'ORIGINALTRAFFICITEMID': 4549054783501400069,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '03/30/2016 13:31:00',
#   'ENDTIME': '08/01/2019 21:00:00',
#   'ENTRYTIME': '07/31/2019 16:20:38',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '23218',
#       'LOCATIONDESC': 'E 6th St',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 735,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Closed due to roadwork.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'E1.C1',
#       'EXTENT': '1',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'Whittier Blvd',
#         'TYPE': 'NTCSA'},
#        {'content': 'Whittier Blvd', 'TYPE': 'RDSGN'},
#        {'content': 'Whittier Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 413},
#      'POINT': {'DESCRIPTION': [{'content': 'US-101/Santa Ana Fwy',
#         'TYPE': 'NTCSA'},
#        {'content': 'US-101/Santa Ana Fwy', 'TYPE': 'RDSGN'},
#        {'content': 'US-101/Santa Ana Fwy', 'TYPE': 'LOCAL'},
#        {'content': 'Whittier Blvd', 'TYPE': 'BNAME'}],
#       'ID': 23218},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'Whittier Blvd',
#         'TYPE': 'NTCSA'},
#        {'content': 'Whittier Blvd', 'TYPE': 'RDSGN'},
#        {'content': 'Whittier Blvd', 'TYPE': 'LOCAL'}],
#       'ID': 413},
#      'POINT': {'DESCRIPTION': [{'content': 'E 6th St', 'TYPE': 'NTCSA'},
#        {'content': 'E 6th St', 'TYPE': 'RDSGN'},
#        {'content': 'E 6th St', 'TYPE': 'LOCAL'},
#        {'content': 'Whittier Blvd', 'TYPE': 'BNAME'}],
#       'ID': 23218},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.036845, 'LONGITUDE': -118.221478},
#     'TO': [{'LATITUDE': 34.03853, 'LONGITUDE': -118.22796}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['764258587',
#       '782857550',
#       '782857551',
#       '909234971',
#       '909234972',
#       '1034454510',
#       '1034454511']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed at E 6th St - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed at E 6th St - Closed due to roadwork.', 'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 2225893758262595530,
#   'ORIGINALTRAFFICITEMID': 3745651032889660529,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/31/2019 21:01:02',
#   'ENDTIME': '08/01/2019 02:00:00',
#   'ENTRYTIME': '07/31/2019 21:01:02',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '17613',
#       'LOCATIONDESC': 'W 1st St/Beverly Blvd/Glendale Blvd',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 735,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Closed due to roadwork.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'E1.C1',
#       'EXTENT': '1',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'Lucas Ave',
#         'TYPE': 'NTCSA'},
#        {'content': 'Lucas Ave', 'TYPE': 'RDSGN'},
#        {'content': 'Lucas Ave', 'TYPE': 'LOCAL'}],
#       'ID': 2095},
#      'POINT': {'DESCRIPTION': [{'content': 'W 1st St/Beverly Blvd/Glendale Blvd',
#         'TYPE': 'NTCSA'},
#        {'content': 'W 1st St/Beverly Blvd/Glendale Blvd', 'TYPE': 'RDSGN'},
#        {'content': 'W 1st St/Beverly Blvd/Glendale Blvd', 'TYPE': 'LOCAL'},
#        {'content': 'Lucas Ave', 'TYPE': 'BNAME'}],
#       'ID': 17613},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'Lucas Ave',
#         'TYPE': 'NTCSA'},
#        {'content': 'Lucas Ave', 'TYPE': 'RDSGN'},
#        {'content': 'Lucas Ave', 'TYPE': 'LOCAL'}],
#       'ID': 2095},
#      'POINT': {'DESCRIPTION': [{'content': 'W 1st St/Beverly Blvd/Glendale Blvd',
#         'TYPE': 'NTCSA'},
#        {'content': 'W 1st St/Beverly Blvd/Glendale Blvd', 'TYPE': 'RDSGN'},
#        {'content': 'W 1st St/Beverly Blvd/Glendale Blvd', 'TYPE': 'LOCAL'},
#        {'content': 'Lucas Ave', 'TYPE': 'BNAME'}],
#       'ID': 17613},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.06205, 'LONGITUDE': -118.25969},
#     'TO': [{'LATITUDE': 34.06205, 'LONGITUDE': -118.25969}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['121236028']}, 'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed at W 1st St/Beverly Blvd/Glendale Blvd - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed at W 1st St/Beverly Blvd/Glendale Blvd - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 46893958378503873,
#   'ORIGINALTRAFFICITEMID': 1618316196432170627,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'ROAD HAZARD',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '07/31/2019 22:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'HAZRD', 'DESCRIPTION': 'rock slide'},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '07332',
#       'LOCATIONDESC': 'Waterman Fire Rd',
#       'RDSDIRECTION': '-'},
#      'TO': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '07333',
#       'LOCATIONDESC': 'NF-3N26c',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 945,
#       'DESCRIPTION': 'Closed due to rockfalls.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 2,
#       'URGENCY': 'U',
#       'UPDATECLASS': 9,
#       'PHRASECODE': 'F8.C1',
#       'EXTENT': '2',
#       'DURATION': 0}},
#     {'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '07332',
#       'LOCATIONDESC': 'Waterman Fire Rd',
#       'RDSDIRECTION': '-'},
#      'TO': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '07333',
#       'LOCATIONDESC': 'NF-3N26c',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 976,
#       'DESCRIPTION': 'Mud slide.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 2,
#       'UPDATECLASS': 12,
#       'PHRASECODE': 'F22',
#       'EXTENT': '2',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'Angeles Crest Hwy',
#         'TYPE': 'NTCSA'},
#        {'content': 'Angeles Crest Hwy', 'TYPE': 'RDSGN'},
#        {'content': 'Angeles Crest Hwy', 'TYPE': 'LOCAL'}],
#       'ID': 528},
#      'POINT': {'DESCRIPTION': [{'content': 'Waterman Fire Rd',
#         'TYPE': 'NTCSA'},
#        {'content': 'Waterman Fire Rd', 'TYPE': 'RDSGN'},
#        {'content': 'Waterman Fire Rd', 'TYPE': 'LOCAL'},
#        {'content': 'Angeles Crest Hwy', 'TYPE': 'BNAME'}],
#       'ID': 7332},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'NF-3n36', 'TYPE': 'NTCSA'},
#        {'content': 'NF-3n36', 'TYPE': 'RDSGN'},
#        {'content': 'NF-3n36', 'TYPE': 'LOCAL'}],
#       'ID': 528},
#      'POINT': {'DESCRIPTION': [{'content': 'NF-3N26c', 'TYPE': 'NTCSA'},
#        {'content': 'NF-3N26c', 'TYPE': 'RDSGN'},
#        {'content': 'NF-3N26c', 'TYPE': 'LOCAL'},
#        {'content': 'NF-3n36', 'TYPE': 'BNAME'}],
#       'ID': 7333},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.25846, 'LONGITUDE': -118.1052},
#     'TO': [{'LATITUDE': 34.37332, 'LONGITUDE': -117.7524}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['775805241',
#       '775805242',
#       '1049784606',
#       '1148999061',
#       '1148999062',
#       '1040769524',
#       '1149162063',
#       '1149162064',
#       '778257074',
#       '775801000',
#       '778257075',
#       '778257076',
#       '1040800378',
#       '1040800379',
#       '1040749545',
#       '776742820',
#       '776742821',
#       '775800899',
#       '775800903',
#       '775800904',
#       '775800900',
#       '23977725',
#       '128820823',
#       '128820821',
#       '1132911224',
#       '1132911225',
#       '1132911222',
#       '1132911223',
#       '1132911221',
#       '776742926',
#       '776742925',
#       '128820862',
#       '128820861',
#       '128820860',
#       '1134056255',
#       '1133159625',
#       '775767799',
#       '775767797',
#       '775767787',
#       '775767788',
#       '775767789',
#       '128820887',
#       '128820886',
#       '775767792',
#       '775767793',
#       '128820900',
#       '128820901',
#       '128837230',
#       '775767795',
#       '775767794',
#       '128820908',
#       '128820909',
#       '775767802',
#       '1140073966',
#       '1134056272',
#       '1132912437',
#       '1132912435',
#       '128820906',
#       '778259286',
#       '864199973',
#       '864199970',
#       '775766857',
#       '1041050573',
#       '1041050572',
#       '775766853',
#       '775766852',
#       '1150105471',
#       '1150105472',
#       '1150092864',
#       '1150092865']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'INCIDENT': {'RESPONSEVEHICLES': False,
#     'ROADHAZARDINCIDENT': {'ROADHAZARDTYPEDESC': 'rock slide'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between Waterman Fire Rd and NF-3N26c - Closed due to rockfalls. Mud slide.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between Waterman Fire Rd and NF-3N26c - Closed due to rockfalls. Mud slide.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to rockfalls. Mud slide.',
#     'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 4245504403590282011,
#   'ORIGINALTRAFFICITEMID': 2329689719556784876,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': '1st St'},
#      'STREET2': {'ADDRESS1': 'W 1st St/Beverly Blvd'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': '1st St'},
#      'STREET2': {'ADDRESS1': 'Glendale Blvd/W 2nd St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.061341, 'LONGITUDE': -118.258692},
#     'TO': [{'LATITUDE': 34.061001, 'LONGITUDE': -118.257955}]},
#    'POLITICALBOUNDARY': {'METROAREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles'},
#    'NAVTECH': {'EDGE': {'EDGEID': ['939442077', '939442076']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between W 1st St/Beverly Blvd and Glendale Blvd/W 2nd St - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between W 1st St/Beverly Blvd and Glendale Blvd/W 2nd St - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 3996656709319688293,
#   'ORIGINALTRAFFICITEMID': 4123157134298454552,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': '2nd Pl'},
#      'STREET2': {'ADDRESS1': 'S Hope St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': '2nd Pl'},
#      'STREET2': {'ADDRESS1': 'W 2nd St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.054907, 'LONGITUDE': -118.251555},
#     'TO': [{'LATITUDE': 34.054636, 'LONGITUDE': -118.251462}]},
#    'POLITICALBOUNDARY': {'METROAREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles'},
#    'NAVTECH': {'EDGE': {'EDGEID': ['121238091']}, 'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between S Hope St and W 2nd St - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between S Hope St and W 2nd St - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 3692713217286682712,
#   'ORIGINALTRAFFICITEMID': 845321475549764405,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'MISCELLANEOUS',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:47',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CLOS', 'DESCRIPTION': ''},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '14768',
#       'LOCATIONDESC': 'I-10/San Bernardino Fwy',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 406,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Entry ramp closed.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 8,
#       'PHRASECODE': 'C6',
#       'EXTENT': '0',
#       'DURATION': 0}},
#     {'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '14768',
#       'LOCATIONDESC': 'I-10/San Bernardino Fwy',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 803,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Construction work.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'UPDATECLASS': 11,
#       'PHRASECODE': 'E11',
#       'EXTENT': '0',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'Kellogg Dr',
#         'TYPE': 'NTCSA'},
#        {'content': 'Kellogg Dr', 'TYPE': 'RDSGN'},
#        {'content': 'Kellogg Dr', 'TYPE': 'LOCAL'}],
#       'ID': 1668},
#      'POINT': {'DESCRIPTION': [{'content': 'I-10/San Bernardino Fwy',
#         'TYPE': 'NTCSA'},
#        {'content': 'I-10/San Bernardino Fwy', 'TYPE': 'RDSGN'},
#        {'content': 'I-10/San Bernardino Fwy', 'TYPE': 'LOCAL'},
#        {'content': 'Kellogg Dr', 'TYPE': 'BNAME'}],
#       'ID': 14768},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'Kellogg Dr',
#         'TYPE': 'NTCSA'},
#        {'content': 'Kellogg Dr', 'TYPE': 'RDSGN'},
#        {'content': 'Kellogg Dr', 'TYPE': 'LOCAL'}],
#       'ID': 1668},
#      'POINT': {'DESCRIPTION': [{'content': 'I-10/San Bernardino Fwy',
#         'TYPE': 'NTCSA'},
#        {'content': 'I-10/San Bernardino Fwy', 'TYPE': 'RDSGN'},
#        {'content': 'I-10/San Bernardino Fwy', 'TYPE': 'LOCAL'},
#        {'content': 'Kellogg Dr', 'TYPE': 'BNAME'}],
#       'ID': 14768},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.06433, 'LONGITUDE': -117.81208},
#     'TO': [{'LATITUDE': 34.06433, 'LONGITUDE': -117.81208}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['799781355']}, 'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': False,
#    'INCIDENT': {'RESPONSEVEHICLES': False,
#     'MISCELLANEOUSINCIDENT': {'MISCELLANEOUSTYPEDESC': ''}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'At I-10/San Bernardino Fwy - Entry ramp closed. Construction work.',
#     'TYPE': 'short_desc'},
#    {'content': 'At I-10/San Bernardino Fwy - Entry ramp closed. Construction work.',
#     'TYPE': 'desc'},
#    {'content': 'Entry ramp closed. Construction work.',
#     'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 1923458635571930844,
#   'ORIGINALTRAFFICITEMID': 1026179930372665385,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '03/30/2016 13:30:00',
#   'ENDTIME': '08/01/2019 21:00:00',
#   'ENTRYTIME': '07/31/2019 16:20:38',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '11203',
#       'LOCATIONDESC': 'Los Angeles River',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 735,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Closed due to roadwork.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'E1.C1',
#       'EXTENT': '1',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'E 6th St',
#         'TYPE': 'NTCSA'},
#        {'content': 'E 6th St', 'TYPE': 'RDSGN'},
#        {'content': 'E 6th St', 'TYPE': 'LOCAL'}],
#       'ID': 912},
#      'POINT': {'DESCRIPTION': [{'content': 'S Alameda St', 'TYPE': 'NTCSA'},
#        {'content': 'S Alameda St', 'TYPE': 'RDSGN'},
#        {'content': 'S Alameda St', 'TYPE': 'LOCAL'},
#        {'content': 'E 6th St', 'TYPE': 'BNAME'}],
#       'ID': 11203},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'E 6th St',
#         'TYPE': 'NTCSA'},
#        {'content': 'E 6th St', 'TYPE': 'RDSGN'},
#        {'content': 'E 6th St', 'TYPE': 'LOCAL'}],
#       'ID': 912},
#      'POINT': {'DESCRIPTION': [{'content': 'Los Angeles River',
#         'TYPE': 'NTCSA'},
#        {'content': 'Los Angeles River', 'TYPE': 'RDSGN'},
#        {'content': 'Los Angeles River', 'TYPE': 'LOCAL'},
#        {'content': 'E 6th St', 'TYPE': 'BNAME'}],
#       'ID': 11203},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'EASTBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'EASTBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'EASTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.038363, 'LONGITUDE': -118.231308},
#     'TO': [{'LATITUDE': 34.03853, 'LONGITUDE': -118.22796}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['1152670932',
#       '1152670933',
#       '128801030',
#       '1084357955',
#       '1084357956',
#       '743359760',
#       '743359759']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed at Los Angeles River - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed at Los Angeles River - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 2478379298139530590,
#   'ORIGINALTRAFFICITEMID': 2145977610821752628,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'MISCELLANEOUS',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'MISC', 'DESCRIPTION': ''},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '23636',
#       'LOCATIONDESC': 'East Fork Rd',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 965,
#       'DESCRIPTION': 'Closed due to serious fire.',
#       'ALERTCDURATION': 'D',
#       'ALERTCDIRECTION': 2,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'F16.C1',
#       'EXTENT': '1',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'Pasadena',
#         'TYPE': 'NTCSA'},
#        {'content': 'Pasadena', 'TYPE': 'RDSGN'},
#        {'content': 'Pasadena', 'TYPE': 'LOCAL'}],
#       'ID': 23634},
#      'POINT': {'DESCRIPTION': [{'content': 'W Sierra Madre Ave/Silverfish',
#         'TYPE': 'NTCSA'},
#        {'content': 'W Sierra Madre Ave/Silverfish', 'TYPE': 'RDSGN'},
#        {'content': 'W Sierra Madre Ave/Silverfish', 'TYPE': 'LOCAL'},
#        {'content': 'Pasadena', 'TYPE': 'BNAME'}],
#       'ID': 23636},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'Pasadena',
#         'TYPE': 'NTCSA'},
#        {'content': 'Pasadena', 'TYPE': 'RDSGN'},
#        {'content': 'Pasadena', 'TYPE': 'LOCAL'}],
#       'ID': 23634},
#      'POINT': {'DESCRIPTION': [{'content': 'East Fork Rd', 'TYPE': 'NTCSA'},
#        {'content': 'East Fork Rd', 'TYPE': 'RDSGN'},
#        {'content': 'East Fork Rd', 'TYPE': 'LOCAL'},
#        {'content': 'Pasadena', 'TYPE': 'BNAME'}],
#       'ID': 23636},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.199964, 'LONGITUDE': -117.860749},
#     'TO': [{'LATITUDE': 34.23911, 'LONGITUDE': -117.85131}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['24003588',
#       '23998410',
#       '128793383',
#       '941563134',
#       '941563135',
#       '775815007',
#       '775815008',
#       '775815005']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'INCIDENT': {'RESPONSEVEHICLES': False,
#     'MISCELLANEOUSINCIDENT': {'MISCELLANEOUSTYPEDESC': ''}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed at East Fork Rd - Closed due to serious fire.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed at East Fork Rd - Closed due to serious fire.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to serious fire.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 513749473938468967,
#   'ORIGINALTRAFFICITEMID': 1581086790607203505,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'MISCELLANEOUS',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CLOS', 'DESCRIPTION': ''},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '05745',
#       'LOCATIONDESC': 'Barranca St/Exit 37B',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 406,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Entry ramp closed.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 8,
#       'PHRASECODE': 'C6',
#       'EXTENT': '0',
#       'DURATION': 0}},
#     {'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '05745',
#       'LOCATIONDESC': 'Barranca St/Exit 37B',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 803,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Construction work.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'UPDATECLASS': 11,
#       'PHRASECODE': 'E11',
#       'EXTENT': '0',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'San Bernardino Fwy',
#         'TYPE': 'NTCSA'},
#        {'content': 'San Bernardino Fwy', 'TYPE': 'RDSGN'},
#        {'content': 'San Bernardino Fwy', 'TYPE': 'LOCAL'}],
#       'ID': 91},
#      'POINT': {'DESCRIPTION': [{'content': 'Barranca St/Exit 37B',
#         'TYPE': 'NTCSA'},
#        {'content': 'Barranca St/Exit 37B', 'TYPE': 'RDSGN'},
#        {'content': 'Barranca St/Exit 37B', 'TYPE': 'LOCAL'},
#        {'content': 'San Bernardino Fwy', 'TYPE': 'BNAME'}],
#       'ID': 5745},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'WESTBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'WESTBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'San Bernardino Fwy',
#         'TYPE': 'NTCSA'},
#        {'content': 'San Bernardino Fwy', 'TYPE': 'RDSGN'},
#        {'content': 'San Bernardino Fwy', 'TYPE': 'LOCAL'}],
#       'ID': 91},
#      'POINT': {'DESCRIPTION': [{'content': 'Barranca St/Exit 37B',
#         'TYPE': 'NTCSA'},
#        {'content': 'Barranca St/Exit 37B', 'TYPE': 'RDSGN'},
#        {'content': 'Barranca St/Exit 37B', 'TYPE': 'LOCAL'},
#        {'content': 'San Bernardino Fwy', 'TYPE': 'BNAME'}],
#       'ID': 5745},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'WESTBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'WESTBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'WESTBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.072, 'LONGITUDE': -117.88428},
#     'TO': [{'LATITUDE': 34.072, 'LONGITUDE': -117.88428}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['735058830', '735058829']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': False,
#    'INCIDENT': {'RESPONSEVEHICLES': False,
#     'MISCELLANEOUSINCIDENT': {'MISCELLANEOUSTYPEDESC': ''}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'At Barranca St/Exit 37B - Entry ramp closed. Construction work.',
#     'TYPE': 'short_desc'},
#    {'content': 'At Barranca St/Exit 37B - Entry ramp closed. Construction work.',
#     'TYPE': 'desc'},
#    {'content': 'Entry ramp closed. Construction work.',
#     'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 709155506245931470,
#   'ORIGINALTRAFFICITEMID': 2906278697779408120,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'MISCELLANEOUS',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CLOS', 'DESCRIPTION': ''},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '18254',
#       'LOCATIONDESC': 'Cecilia St',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 401,
#       'DESCRIPTION': 'Closed.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'C1',
#       'EXTENT': '1',
#       'DURATION': 0}},
#     {'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '18254',
#       'LOCATIONDESC': 'Cecilia St',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 214,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Incident.',
#       'ALERTCDURATION': '(D)',
#       'ALERTCDIRECTION': 1,
#       'UPDATECLASS': 4,
#       'PHRASECODE': 'B14',
#       'EXTENT': '1',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'Orr and Day Rd/Mondon Ave',
#         'TYPE': 'NTCSA'},
#        {'content': 'Orr and Day Rd/Mondon Ave', 'TYPE': 'RDSGN'},
#        {'content': 'Orr and Day Rd/Mondon Ave', 'TYPE': 'LOCAL'}],
#       'ID': 2219},
#      'POINT': {'DESCRIPTION': [{'content': 'Florence Ave', 'TYPE': 'NTCSA'},
#        {'content': 'Florence Ave', 'TYPE': 'RDSGN'},
#        {'content': 'Florence Ave', 'TYPE': 'LOCAL'},
#        {'content': 'Orr and Day Rd/Mondon Ave', 'TYPE': 'BNAME'}],
#       'ID': 18254},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'Orr and Day Rd/Mondon Ave',
#         'TYPE': 'NTCSA'},
#        {'content': 'Orr and Day Rd/Mondon Ave', 'TYPE': 'RDSGN'},
#        {'content': 'Orr and Day Rd/Mondon Ave', 'TYPE': 'LOCAL'}],
#       'ID': 2219},
#      'POINT': {'DESCRIPTION': [{'content': 'Cecilia St', 'TYPE': 'NTCSA'},
#        {'content': 'Cecilia St', 'TYPE': 'RDSGN'},
#        {'content': 'Cecilia St', 'TYPE': 'LOCAL'},
#        {'content': 'Orr and Day Rd/Mondon Ave', 'TYPE': 'BNAME'}],
#       'ID': 18254},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 33.93467, 'LONGITUDE': -118.09056},
#     'TO': [{'LATITUDE': 33.93284, 'LONGITUDE': -118.09033}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['788186179', '788186178', '1128440814']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'INCIDENT': {'RESPONSEVEHICLES': False,
#     'MISCELLANEOUSINCIDENT': {'MISCELLANEOUSTYPEDESC': ''}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed at Cecilia St - Closed. Incident.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed at Cecilia St - Closed. Incident.', 'TYPE': 'desc'},
#    {'content': 'Closed. Incident.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 3108108652506410872,
#   'ORIGINALTRAFFICITEMID': 3304973254627187227,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'MISCELLANEOUS',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CLOS', 'DESCRIPTION': ''},
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Garey St'},
#      'STREET2': {'ADDRESS1': 'E 3rd St/S Alameda St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Garey St'},
#      'STREET2': {'ADDRESS1': 'E 1st St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.04718, 'LONGITUDE': -118.23516},
#     'TO': [{'LATITUDE': 34.04856, 'LONGITUDE': -118.23519}]},
#    'POLITICALBOUNDARY': {'METROAREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles'},
#    'NAVTECH': {'EDGE': {'EDGEID': ['23907850']}, 'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'INCIDENT': {'RESPONSEVEHICLES': False,
#     'MISCELLANEOUSINCIDENT': {'MISCELLANEOUSTYPEDESC': ''}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between E 3rd St/S Alameda St and E 1st St - Closed.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between E 3rd St/S Alameda St and E 1st St - Closed.',
#     'TYPE': 'desc'},
#    {'content': 'Closed.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 1661844553822656019,
#   'ORIGINALTRAFFICITEMID': 3645260180289933598,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Toluca St'},
#      'STREET2': {'ADDRESS1': 'W 1st St/Beverly Blvd'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Toluca St'},
#      'STREET2': {'ADDRESS1': 'W 1st St/Beverly Blvd'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.06155, 'LONGITUDE': -118.25861},
#     'TO': [{'LATITUDE': 34.061231, 'LONGITUDE': -118.258866}]},
#    'POLITICALBOUNDARY': {'METROAREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles'},
#    'NAVTECH': {'EDGE': {'EDGEID': ['732379938', '732379937', '24519582']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed at W 1st St/Beverly Blvd - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed at W 1st St/Beverly Blvd - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 1867745382053432212,
#   'ORIGINALTRAFFICITEMID': 1765718702093797244,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '06/05/2019 05:00:00',
#   'ENDTIME': '08/04/2019 16:18:40',
#   'ENTRYTIME': '07/31/2019 16:20:37',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '11698',
#       'LOCATIONDESC': 'Railroad St',
#       'RDSDIRECTION': '+'},
#      'DIRECTION': '-',
#      'ALERTC': {'TRAFFICCODE': 735,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Closed due to roadwork.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'E1.C1',
#       'EXTENT': '1',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'Fullerton Rd',
#         'TYPE': 'NTCSA'},
#        {'content': 'Fullerton Rd', 'TYPE': 'RDSGN'},
#        {'content': 'Fullerton Rd', 'TYPE': 'LOCAL'}],
#       'ID': 1011},
#      'POINT': {'DESCRIPTION': [{'content': 'Rowland St', 'TYPE': 'NTCSA'},
#        {'content': 'Rowland St', 'TYPE': 'RDSGN'},
#        {'content': 'Rowland St', 'TYPE': 'LOCAL'},
#        {'content': 'Fullerton Rd', 'TYPE': 'BNAME'}],
#       'ID': 11698},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'SOUTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'SOUTHBOUND', 'TYPE': 'RDSGN'}],
# ...
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed at Rowland St - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed at Rowland St - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 4419474409254076395,
#   'ORIGINALTRAFFICITEMID': 87629407419666257,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '11653',
#       'LOCATIONDESC': 'Business Pkwy',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 735,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Closed due to roadwork.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'E1.C1',
#       'EXTENT': '1',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'Fairway Dr',
#         'TYPE': 'NTCSA'},
#        {'content': 'Fairway Dr', 'TYPE': 'RDSGN'},
#        {'content': 'Fairway Dr', 'TYPE': 'LOCAL'}],
#       'ID': 1002},
#      'POINT': {'DESCRIPTION': [{'content': 'Walnut Dr N', 'TYPE': 'NTCSA'},
#        {'content': 'Walnut Dr N', 'TYPE': 'RDSGN'},
#        {'content': 'Walnut Dr N', 'TYPE': 'LOCAL'},
#        {'content': 'Fairway Dr', 'TYPE': 'BNAME'}],
#       'ID': 11653},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'Fairway Dr',
#         'TYPE': 'NTCSA'},
#        {'content': 'Fairway Dr', 'TYPE': 'RDSGN'},
#        {'content': 'Fairway Dr', 'TYPE': 'LOCAL'}],
#       'ID': 1002},
#      'POINT': {'DESCRIPTION': [{'content': 'Business Pkwy', 'TYPE': 'NTCSA'},
#        {'content': 'Business Pkwy', 'TYPE': 'RDSGN'},
#        {'content': 'Business Pkwy', 'TYPE': 'LOCAL'},
#        {'content': 'Fairway Dr', 'TYPE': 'BNAME'}],
#       'ID': 11653},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 33.99838, 'LONGITUDE': -117.87085},
#     'TO': [{'LATITUDE': 33.999574, 'LONGITUDE': -117.871248}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['24052896', '1146054701', '1146054702']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed at Business Pkwy - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed at Business Pkwy - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 3624133431810161829,
#   'ORIGINALTRAFFICITEMID': 3624133431810161829,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'MISCELLANEOUS',
#   'STARTTIME': '11/29/2016 02:14:00',
#   'ENDTIME': '08/30/2019 13:00:00',
#   'ENTRYTIME': '07/17/2019 14:11:38',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CLOS', 'DESCRIPTION': ''},
#   'COMMENTS': 'permanent closure',
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': 'California St'},
#      'STREET2': {'ADDRESS1': 'Alley'},
#      'COUNTY': '',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': 'California St'},
#      'STREET2': {'ADDRESS1': 'Almeda Ave'},
#      'COUNTY': '',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.15593, 'LONGITUDE': -118.33652},
#     'TO': [{'LATITUDE': 34.1555, 'LONGITUDE': -118.33631}]},
#    'POLITICALBOUNDARY': {'METROAREA': {'value': '', 'ID': 6}},
#    'NAVTECH': {'EDGE': {'EDGEID': ['1126566107']}, 'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'INCIDENT': {'RESPONSEVEHICLES': False,
#     'MISCELLANEOUSINCIDENT': {'MISCELLANEOUSTYPEDESC': ''}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between Alley and Almeda Ave - Closed.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between Alley and Almeda Ave - Closed. permanent closure',
#     'TYPE': 'desc'},
#    {'content': 'Closed. permanent closure', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 1077211903505162187,
#   'ORIGINALTRAFFICITEMID': 3630629060176413912,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '14768',
#       'LOCATIONDESC': 'I-10/San Bernardino Fwy',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 735,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Closed due to roadwork.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'E1.C1',
#       'EXTENT': '1',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'Kellogg Dr',
#         'TYPE': 'NTCSA'},
#        {'content': 'Kellogg Dr', 'TYPE': 'RDSGN'},
#        {'content': 'Kellogg Dr', 'TYPE': 'LOCAL'}],
#       'ID': 1668},
#      'POINT': {'DESCRIPTION': [{'content': 'I-10/San Bernardino Fwy',
#         'TYPE': 'NTCSA'},
#        {'content': 'I-10/San Bernardino Fwy', 'TYPE': 'RDSGN'},
#        {'content': 'I-10/San Bernardino Fwy', 'TYPE': 'LOCAL'},
#        {'content': 'Kellogg Dr', 'TYPE': 'BNAME'}],
#       'ID': 14768},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'Kellogg Dr',
#         'TYPE': 'NTCSA'},
#        {'content': 'Kellogg Dr', 'TYPE': 'RDSGN'},
#        {'content': 'Kellogg Dr', 'TYPE': 'LOCAL'}],
#       'ID': 1668},
#      'POINT': {'DESCRIPTION': [{'content': 'I-10/San Bernardino Fwy',
#         'TYPE': 'NTCSA'},
#        {'content': 'I-10/San Bernardino Fwy', 'TYPE': 'RDSGN'},
#        {'content': 'I-10/San Bernardino Fwy', 'TYPE': 'LOCAL'},
#        {'content': 'Kellogg Dr', 'TYPE': 'BNAME'}],
#       'ID': 14768},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.063743, 'LONGITUDE': -117.811997},
#     'TO': [{'LATITUDE': 34.06423, 'LONGITUDE': -117.81207}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['28431302', '1048505121', '1048505122']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed at I-10/San Bernardino Fwy - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed at I-10/San Bernardino Fwy - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 1749675332399442205,
#   'ORIGINALTRAFFICITEMID': 772102148842877395,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': '2nd Pl'},
#      'STREET2': {'ADDRESS1': 'W 2nd St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': '2nd Pl'},
#      'STREET2': {'ADDRESS1': 'S Hope St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.054636, 'LONGITUDE': -118.251462},
#     'TO': [{'LATITUDE': 34.054907, 'LONGITUDE': -118.251555}]},
#    'POLITICALBOUNDARY': {'METROAREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles'},
#    'NAVTECH': {'EDGE': {'EDGEID': ['121238091']}, 'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between W 2nd St and S Hope St - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between W 2nd St and S Hope St - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 4493246509538718554,
#   'ORIGINALTRAFFICITEMID': 1645454903804945641,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'CONSTRUCTION',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CONST', 'DESCRIPTION': 'construction'},
#   'LOCATION': {'INTERSECTION': {'ORIGIN': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Gen Thaddeus Kosciuszko Way'},
#      'STREET2': {'ADDRESS1': 'S Flower St'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}},
#     'TO': {'ID': '',
#      'STREET1': {'ADDRESS1': 'Gen Thaddeus Kosciuszko Way'},
#      'STREET2': {'ADDRESS1': 'Tom Bradley Blvd'},
#      'COUNTY': 'Los Angeles',
#      'STATE': '',
#      'PROXIMITY': {'ID': 'MID', 'DESCRIPTION': 'midway between'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 34.054802, 'LONGITUDE': -118.252773},
#     'TO': [{'LATITUDE': 34.054668, 'LONGITUDE': -118.251734}]},
#    'POLITICALBOUNDARY': {'METROAREA': {'value': '', 'ID': 6},
#     'COUNTY': 'Los Angeles'},
#    'NAVTECH': {'EDGE': {'EDGEID': ['765773120']}, 'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'EVENT': {'EVENTITEMCANCELLED': False,
#     'SCHEDULEDCONSTRUCTIONEVENT': {'SCHEDULEDCONSTRUCTIONTYPEDESC': 'CONSTRUCTION',
#      'SCHEDULEDCONSTRUCTIONDETAIL': 'construction'}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between S Flower St and Tom Bradley Blvd - Closed due to roadwork.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between S Flower St and Tom Bradley Blvd - Closed due to roadwork.',
#     'TYPE': 'desc'},
#    {'content': 'Closed due to roadwork.', 'TYPE': 'no_exit_description'}]},
#  {'TRAFFICITEMID': 1313266060767504707,
#   'ORIGINALTRAFFICITEMID': 3213595257407571511,
#   'TRAFFICITEMSTATUSSHORTDESC': 'ACTIVE',
#   'TRAFFICITEMTYPEDESC': 'MISCELLANEOUS',
#   'STARTTIME': '07/31/2019 20:19:46',
#   'ENDTIME': '08/01/2019 01:18:40',
#   'ENTRYTIME': '07/31/2019 20:19:46',
#   'CRITICALITY': {'ID': '0', 'DESCRIPTION': 'critical'},
#   'VERIFIED': True,
#   'ABBREVIATION': {'SHORTDESC': 'CLOS', 'DESCRIPTION': ''},
#   'RDSTMCLOCATIONS': {'RDSTMC': [{'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '18254',
#       'LOCATIONDESC': 'Cecilia St',
#       'RDSDIRECTION': '-'},
#      'TO': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '18255',
#       'LOCATIONDESC': 'Florence Ave',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 401,
#       'DESCRIPTION': 'Closed.',
#       'ALERTCDURATION': 'L',
#       'ALERTCDIRECTION': 1,
#       'URGENCY': 'U',
#       'UPDATECLASS': 5,
#       'PHRASECODE': 'C1',
#       'EXTENT': '1',
#       'DURATION': 0}},
#     {'ORIGIN': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '18254',
#       'LOCATIONDESC': 'Cecilia St',
#       'RDSDIRECTION': '-'},
#      'TO': {'EBUCOUNTRYCODE': '1',
#       'TABLEID': 6,
#       'LOCATIONID': '18255',
#       'LOCATIONDESC': 'Florence Ave',
#       'RDSDIRECTION': '-'},
#      'DIRECTION': '+',
#      'ALERTC': {'TRAFFICCODE': 214,
#       'QUANTIFIERS': 0,
#       'DESCRIPTION': 'Incident.',
#       'ALERTCDURATION': '(D)',
#       'ALERTCDIRECTION': 1,
#       'UPDATECLASS': 4,
#       'PHRASECODE': 'B14',
#       'EXTENT': '1',
#       'DURATION': 0}}]},
#   'LOCATION': {'DEFINED': {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'content': 'Orr and Day Rd/Mondon Ave',
#         'TYPE': 'NTCSA'},
#        {'content': 'Orr and Day Rd/Mondon Ave', 'TYPE': 'RDSGN'},
#        {'content': 'Orr and Day Rd/Mondon Ave', 'TYPE': 'LOCAL'}],
#       'ID': 2219},
#      'POINT': {'DESCRIPTION': [{'content': 'Cecilia St', 'TYPE': 'NTCSA'},
#        {'content': 'Cecilia St', 'TYPE': 'RDSGN'},
#        {'content': 'Cecilia St', 'TYPE': 'LOCAL'},
#        {'content': 'Orr and Day Rd/Mondon Ave', 'TYPE': 'BNAME'}],
#       'ID': 18254},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}},
#     'TO': {'ROADWAY': {'DESCRIPTION': [{'content': 'Orr and Day Rd/Mondon Ave',
#         'TYPE': 'NTCSA'},
#        {'content': 'Orr and Day Rd/Mondon Ave', 'TYPE': 'RDSGN'},
#        {'content': 'Orr and Day Rd/Mondon Ave', 'TYPE': 'LOCAL'}],
#       'ID': 2219},
#      'POINT': {'DESCRIPTION': [{'content': 'Florence Ave', 'TYPE': 'NTCSA'},
#        {'content': 'Florence Ave', 'TYPE': 'RDSGN'},
#        {'content': 'Florence Ave', 'TYPE': 'LOCAL'},
#        {'content': 'Orr and Day Rd/Mondon Ave', 'TYPE': 'BNAME'}],
#       'ID': 18255},
#      'DIRECTION': {'DESCRIPTION': [{'content': 'NORTHBOUND', 'TYPE': 'LOCAL'},
#        {'content': 'NORTHBOUND', 'TYPE': 'NTCSA'},
#        {'content': 'NORTHBOUND', 'TYPE': 'RDSGN'}],
#       'ID': 0},
#      'PROXIMITY': {'ID': 'AT', 'DESCRIPTION': 'at'}}},
#    'GEOLOC': {'ORIGIN': {'LATITUDE': 33.93284, 'LONGITUDE': -118.09033},
#     'TO': [{'LATITUDE': 33.93467, 'LONGITUDE': -118.09056}]},
#    'NAVTECH': {'EDGE': {'EDGEID': ['1128440814', '788186178', '788186179']},
#     'VERSIONID': '201902'}},
#   'TRAFFICITEMDETAIL': {'ROADCLOSED': True,
#    'INCIDENT': {'RESPONSEVEHICLES': False,
#     'MISCELLANEOUSINCIDENT': {'MISCELLANEOUSTYPEDESC': ''}}},
#   'TRAFFICITEMDESCRIPTION': [{'content': 'Closed between Cecilia St and Florence Ave - Closed. Incident.',
#     'TYPE': 'short_desc'},
#    {'content': 'Closed between Cecilia St and Florence Ave - Closed. Incident.',
#     'TYPE': 'desc'},
#    {'content': 'Closed. Incident.', 'TYPE': 'no_exit_description'}]}]

# %%
# Turn dictionary into DataFrame
LA_incidents2 = pd.DataFrame(incident_dict)

# %%
# Check how many current roads are closed.  Rows = # of incidents 
LA_incidents2.shape
# Out:
# (44, 15)

# %%
#Check column names
LA_incidents2.columns
# Out:
# Index(['ABBREVIATION', 'COMMENTS', 'CRITICALITY', 'ENDTIME', 'ENTRYTIME',
#        'LOCATION', 'ORIGINALTRAFFICITEMID', 'RDSTMCLOCATIONS', 'STARTTIME',
#        'TRAFFICITEMDESCRIPTION', 'TRAFFICITEMDETAIL', 'TRAFFICITEMID',
#        'TRAFFICITEMSTATUSSHORTDESC', 'TRAFFICITEMTYPEDESC', 'VERIFIED'],
#       dtype='object')

# %%
# Check one incident for closed road name. 
# LA_incidents2['LOCATION'][4]['DEFINED']['ORIGIN']['ROADWAY']['DESCRIPTION'][0]['content']

# %% [markdown]
# The names of the actual closed roads were in two different locations in the nested dictionaries so we had to pull from each separately and them combine into one column.

# %%
# Loop through nested dictionary to find name of closed road in ['DEFINED'] key and return as a list.
# If empty, fill in with 'uknown' and keeping looping.
roads1 = []
for i in range(0, LA_incidents2.shape[0]):
    try:
        word = LA_incidents2['LOCATION'][i]['DEFINED']['ORIGIN']['ROADWAY']['DESCRIPTION'][0]['content']
        roads1.append(word)
    except:
        roads1.append('unknown')

# %%
# Turn list into a DataFrame and rename column.
roads1 = pd.DataFrame(roads1).rename(columns={0: 'closed_road1'})
roads1.head()
# Out:
#          closed_road1
# 0            Pasadena
# 1             unknown
# 2             unknown
# 3  San Bernardino Fwy
# 4       Whittier Blvd

# %%
# Loop through nested dictionary to find name of closed road in ['ORIGIN'] key and return as a list.
# If empty, fill in with 'uknown' and keeping looping.

road2 = []
for i in range(0,LA_incidents2.shape[0]):
    try:
        word = locations['INTERSECTION'][i]['ORIGIN']['STREET1']['ADDRESS1']
        road2.append(word)
    except:
        road2.append('unknown')

roads2 = pd.DataFrame(road2).rename(columns={0:'closed_road2'})
roads2.head()
# Out:
#   closed_road2
# 0      unknown
# 1     Garey St
# 2    Ramona Rd
# 3      unknown
# 4      unknown

# %%
#Concatonate the two Roads DataFrames on the columns 
all_roads = pd.concat((roads1, roads2), axis=1)

#Add the strings in each column together into one column.
all_roads['Closed Roads'] = all_roads['closed_road1'] + all_roads['closed_road2']

#Strip 'unknown' off the strings on the front and/or back end. 
all_roads['Closed Roads'] = all_roads['Closed Roads'].str.strip('unknown')

#Drop the original roads columns, leaving one final Series of all the closed roads.
all_roads.drop(columns=['closed_road1', 'closed_road2'], inplace=True)

all_roads.head()
# Out:
# 0              Pasadena
# 1              Garey St
# 2             Ramona Rd
# 3    San Bernardino Fwy
# 4         Whittier Blvd
# Name: Closed Roads, dtype: object
#          Closed Roads
# 0            Pasadena
# 1            Garey St
# 2           Ramona Rd
# 3  San Bernardino Fwy
# 4       Whittier Blvd

# %%
# Check traffic description output 
# LA_incidents2['TRAFFICITEMDESCRIPTION'][43][0]['content']

# %%
# Loop through TRAFFICITEMDESCRIPTION dictionary to get details of closure start and end points. 
# Return a list of all closure details.
start_end = []
for i in range(0,LA_incidents2.shape[0]):
    try:
        word = LA_incidents2['TRAFFICITEMDESCRIPTION'][i][0]['content']
        start_end.append(word)
    except:
        start_end.append('unknown')

# %%
# Save list as a DataFrame 
start_end_df = pd.DataFrame(start_end)

# Closure details column also included closure type, so we split type into it's own column. 
start_end_type = start_end_df[0].str.split(" - Closed", n=1, expand=True).rename(columns={0: 'Closure Details', 1: 'Closure Type'})

#Check output 
start_end_type.head()
# Out:
#                                      Closure Details           Closure Type
# 0            Closed at W Sierra Madre Ave/Silverfish   due to serious fire.
# 1  Closed between E 1st St and E 3rd St/S Alameda St                      .
# 2  Closed between I-10/San Bernardino Fwy and I-1...       due to roadwork.
# 3  At CA-39/Azusa Ave/Exit 36 - Entry ramp closed...                   None
# 4                                 Closed at E 6th St       due to roadwork.

# %%
#Turn LOCATIONS key into a DataFrame
locations = pd.DataFrame(list(LA_incidents2['LOCATION']))

#Check head of DataFrame
locations.head()
# Out:
#                                              DEFINED  \
# 0  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'cont...
# 1                                                NaN
# 2                                                NaN
# 3  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'cont...
# 4  {'ORIGIN': {'ROADWAY': {'DESCRIPTION': [{'cont...
#
#                                               GEOLOC  \
# 0  {'ORIGIN': {'LATITUDE': 34.23911, 'LONGITUDE':...
# 1  {'ORIGIN': {'LATITUDE': 34.04856, 'LONGITUDE':...
# 2  {'ORIGIN': {'LATITUDE': 34.06572, 'LONGITUDE':...
# 3  {'ORIGIN': {'LATITUDE': 34.07201, 'LONGITUDE':...
# 4  {'ORIGIN': {'LATITUDE': 34.036845, 'LONGITUDE'...
#
#                                         INTERSECTION  \
# 0                                                NaN
# 1  {'ORIGIN': {'ID': '', 'STREET1': {'ADDRESS1': ...
# 2  {'ORIGIN': {'ID': '', 'STREET1': {'ADDRESS1': ...
# 3                                                NaN
# 4                                                NaN
#
#                                              NAVTECH  \
# 0  {'EDGE': {'EDGEID': ['775815005', '775815008',...
# 1  {'EDGE': {'EDGEID': ['23907850']}, 'VERSIONID'...
# 2  {'EDGE': {'EDGEID': ['955186417', '23910120']}...
# 3  {'EDGE': {'EDGEID': ['24041211']}, 'VERSIONID'...
# 4  {'EDGE': {'EDGEID': ['764258587', '782857550',...
#
#                                    POLITICALBOUNDARY
# 0                                                NaN
# 1  {'METROAREA': {'value': '', 'ID': 6}, 'COUNTY'...
# 2  {'METROAREA': {'value': '', 'ID': 6}, 'COUNTY'...
# 3                                                NaN
# 4                                                NaN

# %%
# Turn GEOLOC nested dictionary into a DataFrame 
geo_coor = pd.DataFrame(list(locations['GEOLOC']))

# Check head of DataFrame
geo_coor.head()
# Out:
#                                               ORIGIN  \
# 0    {'LATITUDE': 34.23911, 'LONGITUDE': -117.85131}
# 1    {'LATITUDE': 34.04856, 'LONGITUDE': -118.23519}
# 2    {'LATITUDE': 34.06572, 'LONGITUDE': -118.15693}
# 3    {'LATITUDE': 34.07201, 'LONGITUDE': -117.90261}
# 4  {'LATITUDE': 34.036845, 'LONGITUDE': -118.221478}
#
#                                                   TO
# 0  [{'LATITUDE': 34.199964, 'LONGITUDE': -117.860...
# 1  [{'LATITUDE': 34.04718, 'LONGITUDE': -118.23516}]
# 2  [{'LATITUDE': 34.06708, 'LONGITUDE': -118.15434}]
# 3  [{'LATITUDE': 34.07201, 'LONGITUDE': -117.90261}]
# 4  [{'LATITUDE': 34.03853, 'LONGITUDE': -118.22796}]

# %%
# ORIGIN column is in dictionary format so you can split 
origin = geo_coor['ORIGIN'].apply(pd.Series).rename(columns={'LATITUDE': 'Latitude', 'LONGITUDE': 'Longitude'})
origin.head()
# Out:
#     Latitude   Longitude
# 0  34.239110 -117.851310
# 1  34.048560 -118.235190
# 2  34.065720 -118.156930
# 3  34.072010 -117.902610
# 4  34.036845 -118.221478

# %%
#A list of DataFrames to be concatonated
dataframes = [all_roads, start_end_type, origin]

# Concat all 3 DataFrames into one, along the column axis.
total_LA_closures = pd.concat(dataframes, axis=1)

# %%
total_LA_closures
# Out:
#                    Closed Roads  \
# 0                      Pasadena
# 1                      Garey St
# 2                     Ramona Rd
# 3            San Bernardino Fwy
# 4                 Whittier Blvd
# 5                     Lucas Ave
# 6             Angeles Crest Hwy
# 7                        1st St
# 8                        2nd Pl
# 9                    Kellogg Dr
# 10                     E 6th St
# 11                     Pasadena
# 12           San Bernardino Fwy
# 13    Orr and Day Rd/Mondon Ave
# 14                     Garey St
# 15                    Toluca St
# 16                 Fullerton Rd
# 17                Santa Ana Fwy
# 18                    Toluca St
# 19                Whittier Blvd
# 20                    Sunset Pl
# 21                       6th St
# 22              S Hacienda Blvd
# 23           San Bernardino Fwy
# 24                     E 6th St
# 25                    Ramona Rd
# 26                        CA-39
# 27                 Leighton Ave
# 28                California St
# 29           San Bernardino Fwy
# 30                 Leighton Ave
# 31                   Empire Ave
# 32                    Lucas Ave
# 33                Hacienda Blvd
# 34                   Empire Ave
# 35                   Fairway Dr
# 36                Santa Ana Fwy
# 37                 Fullerton Rd
# 38                   Fairway Dr
# 39                California St
# 40                   Kellogg Dr
# 41                       2nd Pl
# 42  Gen Thaddeus Kosciuszko Way
# 43    Orr and Day Rd/Mondon Ave
#
#                                       Closure Details  \
# 0             Closed at W Sierra Madre Ave/Silverfish
# 1   Closed between E 1st St and E 3rd St/S Alameda St
# 2   Closed between I-10/San Bernardino Fwy and I-1...
# 3   At CA-39/Azusa Ave/Exit 36 - Entry ramp closed...
# 4                                  Closed at E 6th St
# 5       Closed at W 1st St/Beverly Blvd/Glendale Blvd
# 6        Closed between Waterman Fire Rd and NF-3N26c
# 7   Closed between W 1st St/Beverly Blvd and Glend...
# 8               Closed between S Hope St and W 2nd St
# 9   At I-10/San Bernardino Fwy - Entry ramp closed...
# 10                        Closed at Los Angeles River
# 11                             Closed at East Fork Rd
# 12  At Barranca St/Exit 37B - Entry ramp closed. C...
# 13                               Closed at Cecilia St
# 14  Closed between E 3rd St/S Alameda St and E 1st St
# 15                    Closed at W 1st St/Beverly Blvd
# 16                              Closed at Railroad St
# 17              Ramp  closed to Florence Ave/Exit 123
# 18                    Closed at W 1st St/Beverly Blvd
# 19   Closed between E 6th St and US-101/Santa Ana Fwy
# 20           Closed between Wilshire Pl and Hoover St
# 21                                 Closed at E 6th St
# 22                        Closed at CR-N8/E Colima Rd
# 23                    At Holt Ave - Exit ramp closed.
# 24  Closed between Los Angeles River and S Alameda St
# 25  Closed between I-10/San Bernardino Fwy/Bus Ln ...
# 26  Closed between NF-3N09 and CA-39/N San Gabriel...
# 27  Closed between Martin Luther King Jr Blvd and ...
# 28                Closed between Almeda Ave and Alley
# 29                   At Holt Ave - Entry ramp closed.
# 30  Closed between Exposition Blvd and Martin Luth...
# 31           Closed between Victory Pl and Wilson Ave
# 32      Closed at W 1st St/Beverly Blvd/Glendale Blvd
# 33                                  Closed at East Rd
# 34           Closed between Wilson Ave and Victory Pl
# 35                              Closed at Walnut Dr N
# 36                  Ramp  closed to I-5/Santa Ana Fwy
# 37                               Closed at Rowland St
# 38                            Closed at Business Pkwy
# 39                Closed between Alley and Almeda Ave
# 40                  Closed at I-10/San Bernardino Fwy
# 41              Closed between W 2nd St and S Hope St
# 42    Closed between S Flower St and Tom Bradley Blvd
# 43         Closed between Cecilia St and Florence Ave
#
#                        Closure Type   Latitude   Longitude
# 0              due to serious fire.  34.239110 -117.851310
# 1                                 .  34.048560 -118.235190
# 2                  due to roadwork.  34.065720 -118.156930
# 3                              None  34.072010 -117.902610
# 4                  due to roadwork.  34.036845 -118.221478
# 5                  due to roadwork.  34.062050 -118.259690
# 6      due to rockfalls. Mud slide.  34.258460 -118.105200
# 7                  due to roadwork.  34.061341 -118.258692
# 8                  due to roadwork.  34.054907 -118.251555
# 9                              None  34.064330 -117.812080
# 10                 due to roadwork.  34.038363 -118.231308
# 11             due to serious fire.  34.199964 -117.860749
# 12                             None  34.072000 -117.884280
# 13                      . Incident.  33.934670 -118.090560
# 14                                .  34.047180 -118.235160
# 15                 due to roadwork.  34.061550 -118.258610
# 16                 due to roadwork.  34.002905 -117.904211
# 17                 due to roadwork.  33.936220 -118.094810
# 18                 due to roadwork.  34.061231 -118.258866
# 19                 due to roadwork.  34.038432 -118.227522
# 20                 due to roadwork.  34.060750 -118.287820
# 21                 due to roadwork.  34.038530 -118.230540
# 22  . Hazardous driving conditions.  33.958114 -117.958232
# 23                             None  34.068730 -117.861190
# 24                 due to roadwork.  34.038564 -118.228276
# 25                 due to roadwork.  34.067080 -118.154340
# 26                                .  34.309010 -117.854820
# 27                                .  34.013231 -118.290893
# 28                                .  34.155500 -118.336310
# 29                             None  34.070320 -117.864340
# 30                                .  34.013237 -118.291329
# 31                 due to roadwork.  34.192080 -118.329290
# 32                 due to roadwork.  34.062050 -118.259690
# 33  . Hazardous driving conditions.  33.976507 -117.969467
# 34                 due to roadwork.  34.191800 -118.331430
# 35                 due to roadwork.  33.999664 -117.871428
# 36                 due to roadwork.  33.935380 -118.090630
# 37                 due to roadwork.  33.996874 -117.904940
# 38                 due to roadwork.  33.998380 -117.870850
# 39                                .  34.155930 -118.336520
# 40                 due to roadwork.  34.063743 -117.811997
# 41                 due to roadwork.  34.054636 -118.251462
# 42                 due to roadwork.  34.054802 -118.252773
# 43                      . Incident.  33.932840 -118.090330

# %%
# Save to a csv.  Commented out so as so not override the save every time the notebook is run.
# total_LA_closures.to_csv('live_here_locations.csv')
